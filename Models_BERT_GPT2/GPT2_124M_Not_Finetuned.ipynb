# %% [markdown]
# **GPT-2 124M NOT fine-tuned**
#
# source:         https://medium.com/analytics-vidhya/an-ai-that-does-your-homework-e5fa40c43d17
#
# gpt-2 source:   https://colab.research.google.com/drive/1VLG8e7YSEwypxU-noRNhsv5dW4NfTGce#scrollTo=BT__brhBCvJu

# %%
# code breaker
# the purpose of this line is to break the code
# so the whole colab does not run by accident
# print(break_the_code)

# %% [markdown]
# **Key steps to prepare the GPT-2 model to be used**

# %%
# Step 1: install GPT-2 model
# !pip install -q gpt-2-simple
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for gpt-2-simple (setup.py) ... done

# %%
# Step 2: import gpt-2 model
import gpt_2_simple as model

# %%
# Step 3: download GPT-2 124M model
model.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 2.82Git/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.70Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 1.24Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:09, 51.0Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 2.29Git/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 8.61Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 6.42Mit/s]

# %%
# Step 4: import datetime and files
from datetime import datetime
from google.colab import files

# %%
# Step 5: load the model
sess = model.start_tf_sess()
model.load_gpt2(sess, model_name="124M")
# Out:
# Loading pretrained model models/124M/model.ckpt

# %%
# Step 6: function generates answer to the question
def generateAnswer(question):
    model.generate(sess,
              model_name="124M",
              prefix=question,
              length=50,
              temperature=0.7,
              #top_p=0.9,
              nsamples=1,
              #batch_size=1
              )

# %% [markdown]
# **Steps to prepare datasets - not important**

# %%
# mount drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# set path to datasets
path = "/content/gdrive/My Drive/Models_BERT_GPT2/"
print(path)
# Out:
# /content/gdrive/My Drive/Models_BERT_GPT2/

# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# import regex to remove the \n \t \r
import re
regex = re.compile(r'[\n\r\t]')

# %%
# Alternative Products dataset

# variable
tempText = ""

# read file
file = open(path+"AlternativeProductsCleaned.txt", "r")
line = file.read()

# prepare each line
tempText += line

# gesplit temporary texdt tempText into tokens
tokens = tempText.split(':')

# keyword and answer
keyword = ""
answer = ""

# index used when looping through tokens
index = 0
# index used when inserting data into dataset array
datasetIndex = 0

# alternativeProductsData used to collect data
alternativeProductsData = []

# loop thorugh tokens
for token in tokens:

  # line is contains keyword, product to be replaced
  if index%2==0:
    token = token.replace("'","")
    token = regex.sub(' ', token)
    token = token.strip()
    keyword = token
    question = "What can be used to replace "+keyword+"?"
    # print(question)

  # line contains alternative products
  elif index%2!=0:
    #answer = token.replace(", do you have any of these ingredients?","")
    answer = regex.sub(' ', token)
    answer = answer.strip()
    answer = answer
    text = "If you do not have "+keyword+" "+answer
    # print(text)

  # add question and text to the dataset
  if index>0 and index%2!=0:
    alternativeProductsData.append({"question":question,"context":text})
    datasetIndex = datasetIndex + 1

  # increase index
  index = index+ 1

# global alternativeProducts
alternativeProducts = pd.DataFrame(alternativeProductsData)

# print alternativeProducts
for i in range (len(alternativeProducts)):
    question = alternativeProducts["question"][i]
    context = alternativeProducts["context"][i]
    print(i+1)
    print(question)
    print(context)
    print("")
# Out:
# 1
# What can be used to replace plain flour?
# If you do not have plain flour oat flour, bread flour, cake flour or coconut flour
#
# 2
# What can be used to replace olive oil?
# If you do not have olive oil peanut oil, butter, coconut milk, ghee, walnut oil, sunflower oil, canola oil or vegetable oil
#
# 3
# What can be used to replace salt?
# If you do not have salt mint, rosemary, nutmeg, basil, cardamon, chili, cinnamon or chives
#
# 4
# What can be used to replace black pepper?
# If you do not have black pepper white pepper, cayenne pepper or papaya seeds
#
# 5
# What can be used to replace eggs?
# If you do not have eggs commerical egg substitute or tofu
#
# 6
# What can be used to replace milk?
# If you do not have milk cream, powerdered milk, plain yogurt, nut milk, soy milk, oat milk or rice milk
#
# 7
# What can be used to replace sausage?
# If you do not have sausage vegetarian sausages
#
# 8
# What can be used to replace mustard?
# If you do not have mustard turmeric, wasabi powder or horseradish powder
#
# 9
# What can be used to replace beef stock?
# If you do not have beef stock vegetable stock, chicken stock, bouillion stock or red wine
#
# 10
# What can be used to replace cabbage?
# If you do not have cabbage brussels sprouts, yu choy, kangkong or bok choy
#
# 11
# What can be used to replace garlic?
# If you do not have garlic garlic oil, onion, chives or lemon zest
#
# 12
# What can be used to replace mixed herbs?
# If you do not have mixed herbs basil, marjoram, min, oregano or parsley
#
# 13
# What can be used to replace butter?
# If you do not have butter olive oil, ghee, greek yogurt, avocado, pumpkin puree or coconut oil
#
# 14
# What can be used to replace potato?
# If you do not have potato cauliflower or cabbage
#
# 15
# What can be used to replace frozen peas?
# If you do not have frozen peas lima beans, green pepper, green onion or broad beans
#
# 16
# What can be used to replace mushrooms?
# If you do not have mushrooms zucchini, eggplant, chickpeas, tofu, onions or cilantro
#
# 17
# What can be used to replace oat meal?
# If you do not have oat meal amaranth, teff, buckwheat, wheat berries, spelt or quinoa
#
# 18
# What can be used to replace yeast?
# If you do not have yeast baking powder. baking soda or sourdough
#
# 19
# What can be used to replace bacon?
# If you do not have bacon pork, chicken or turkey bacon
#
# 20
# What can be used to replace tomatoes?
# If you do not have tomatoes olives, red peppers or red capsicum
#
# 21
# What can be used to replace baked beans?
# If you do not have baked beans peas or chickpeas
#
# 22
# What can be used to replace paprika?
# If you do not have paprika catenne pepper, chili powder or chili flakes
#
# 23
# What can be used to replace feta?
# If you do not have feta ricotta, halloumi, goats cheese or queso fresco
#
# 24
# What can be used to replace parsley?
# If you do not have parsley chervil, tarragon, chives, oregano, arugula, endive, cilantro or basil
#
# 25
# What can be used to replace cheddar?
# If you do not have cheddar cantal, edam, mimolette, gouda, emmental or french gruyere
#
# 26
# What can be used to replace pork fillet?
# If you do not have pork fillet pork sirloin, pork tenderloin, chicken, turkey or beef
#
# 27
# What can be used to replace red peppers?
# If you do not have red peppers poblano peppers, cubanelle, anaheim peppers, pepperoncini, jalapeno, pimiento, zucchini or broccoli
#
# 28
# What can be used to replace courgette?
# If you do not have courgette cucumber or zucchini
#
# 29
# What can be used to replace chickpeas?
# If you do not have chickpeas green peas, cannellini beans, black beans, lentils, soybeans, mung beans, peanuts or hazelnuts
#
# 30
# What can be used to replace chicken stock?
# If you do not have chicken stock beef stock or vegatable stock
#
# 31
# What can be used to replace muscovado sugar?
# If you do not have muscovado sugar demerara sugar or brown sugar
#
# 32
# What can be used to replace balsamic vinegar?
# If you do not have balsamic vinegar red wine vinegar, lemon juice or lime juice
#
# 33
# What can be used to replace paraham?
# If you do not have paraham smoked ham, pork chops, bacon, prosciutti or cooked ham
#
# 34
# What can be used to replace passata?
# If you do not have passata tomatoes. pasta sauce, tomato paste, ketchup or fresh tomatoes
#
# 35
# What can be used to replace goats cheese?
# If you do not have goats cheese cream cheese, mascarpone cheese, feta cheese or ricotta cheese
#
# 36
# What can be used to replace basil?
# If you do not have basil marajoram, mint, parsley, oregano or thyme
#
# 37
# What can be used to replace golden syrup?
# If you do not have golden syrup honey, cane syrup or brown rice syrup
#
# 38
# What can be used to replace breadcrumbs?
# If you do not have breadcrumbs oats, chrshed chips, nuts, crackers, pretzels or cereal
#
# 39
# What can be used to replace lemon?
# If you do not have lemon lime. orange, white wine, cream of tartar or citric acid
#
# 40
# What can be used to replace sunflower oil?
# If you do not have sunflower oil vegetable oil, peanut oil, canola oil, walnut oil, butter, safflower oil, corn oil or grapeseed oil
#
# 41
# What can be used to replace sweet potato?
# If you do not have sweet potato garnet potatoes, jewel potatoes, yukon potatoes, carrots, parsnips, pumpkin or butternut
#
# 42
# What can be used to replace apple?
# If you do not have apple pear
#
# 43
# What can be used to replace curry powder?
# If you do not have curry powder cumin, coriander, chilli, tumeric or black pepper
#
# 44
# What can be used to replace tomato puree?
# If you do not have tomato puree tomato sauce, pizza sauce, tomato, canned tomatoes or ketchup
#
# 45
# What can be used to replace mango chutney?
# If you do not have mango chutney apricot, mango salsa or marmalade
#
# 46
# What can be used to replace basmati rice?
# If you do not have basmati rice jasmine rice, brown rice, white rice or texmati rice
#
# 47
# What can be used to replace sour cream?
# If you do not have sour cream greek jogurt, cottage cheese, creme fraiche or buttermilk
#
# 48
# What can be used to replace coriander?
# If you do not have coriander cumin, garam masala, curry powder or caraway
#
# 49
# What can be used to replace braising steak?
# If you do not have braising steak diced beef, sirloin steak or rump steak
#
# 50
# What can be used to replace brown ale?
# If you do not have brown ale beef stock, chicken stock or vegatable stock
#
# 51
# What can be used to replace celery?
# If you do not have celery fennel, onion, scallions, carrots, shallots, garlic, chives or leeks
#
# 52
# What can be used to replace bay leaf?
# If you do not have bay leaf thyme, oregano or boldo leaf
#
# 53
# What can be used to replace thyme?
# If you do not have thyme oregano, marjoram, rosemary, savoury or basil
#
# 54
# What can be used to replace carrots?
# If you do not have carrots parsnips, daikon, turnip or celery
#
# 55
# What can be used to replace onions?
# If you do not have onions leeks, chives, garlic, carrors or tomatoes
#
# 56
# What can be used to replace cornstarch?
# If you do not have cornstarch wheat flour, arrowroot, potao starch, rice flour, ground flaxseeds, glucomannan or psyllium husk
#
# 57
# What can be used to replace pectin?
# If you do not have pectin citrus peels, cornstarch or geletine
#
# 58
# What can be used to replace heavy cream?
# If you do not have heavy cream milk and butter combined, soy milks and olive oil, milk and cornstarch, greek yogurt, evaporated milk or cottage cheese and milk
#
# 59
# What can be used to replace vegetable shortening?
# If you do not have vegetable shortening butter or magarine
#
# 60
# What can be used to replace vanilla extract?
# If you do not have vanilla extract maple syrup, almond extract, bourbon, brandy, rum
#
# 61
# What can be used to replace powdered sugar?
# If you do not have powdered sugar sweetner or cornstarch
#
# 62
# What can be used to replace maple syrup?
# If you do not have maple syrup honey, corn syrup or agave nectar
#
# 63
# What can be used to replace sprinkles?
# If you do not have sprinkles brown sugar or honey
#
# 64
# What can be used to replace cinnamon powder?
# If you do not have cinnamon powder all spice or or nutmeg
#
# 65
# What can be used to replace cooking spray?
# If you do not have cooking spray butter or olive oil
#
# 66
# What can be used to replace canned pumpkin?
# If you do not have canned pumpkin mashed sweet potato or butternut squash
#
# 67
# What can be used to replace brown sugar?
# If you do not have brown sugar white sugar, honey, maple syrup, coconut sugar or muscovado sugar
#
# 68
# What can be used to replace pumpkin?
# If you do not have pumpkin butternut, honeynut or acorn squash
#
# 69
# What can be used to replace cinamon?
# If you do not have cinamon cassia, allspice, clives, nutmeg or cardamom
#
# 70
# What can be used to replace nutmeg?
# If you do not have nutmeg mace, garam masala, allspice, cinnamon, apple pie spice, giner or cloves
#
# 71
# What can be used to replace allspice?
# If you do not have allspice cinnamon, nutmeg, cloves or applie pie spice
#
# 72
# What can be used to replace ground cloves?
# If you do not have ground cloves allspice, caradamon, pumpkin pie spice or cinnamon
#
# 73
# What can be used to replace ginger?
# If you do not have ginger cardamom, allspice, cinnamon, nutmeg or mace
#
# 74
# What can be used to replace berbere seasoning?
# If you do not have berbere seasoning cayenne pepper or ras el hanout
#
# 75
# What can be used to replace tomato paste?
# If you do not have tomato paste soy sauce, olive tapenade, canned tomatoes or tomato ketchup
#
# 76
# What can be used to replace red lentils?
# If you do not have red lentils yellow lentils or green lentils
#
# 77
# What can be used to replace strawberries?
# If you do not have strawberries rasberries, red grapes or blueberries
#
# 78
# What can be used to replace pineapple?
# If you do not have pineapple apple, orange, kiwi or grape
#
# 79
# What can be used to replace red onion?
# If you do not have red onion yellow onions, leeks, shallots or onion juice, poweder or flakes
#
# 80
# What can be used to replace cilantro?
# If you do not have cilantro parsley, mint, basil, chives, green onions, dill or carrot greens
#
# 81
# What can be used to replace key lime juice?
# If you do not have key lime juice lemon juice or lemon extract
#
# 82
# What can be used to replace unsalted butter?
# If you do not have unsalted butter maragarine, vegetable shortening, coconut oil or salted butter
#
# 83
# What can be used to replace egg yolk?
# If you do not have egg yolk apple sauce, mashed banana, ground flaxseeds, chia seeds, commerial egg replacer, silken tofu or buttermilk
#
# 84
# What can be used to replace pear?
# If you do not have pear apples, asain pears, quinces, figs or pepinos
#
# 85
# What can be used to replace lemon juice?
# If you do not have lemon juice lime juice, orange juice, vinegar, citric acid, white wine, lemon extract or cream or tartar
#
# 86
# What can be used to replace black beans?
# If you do not have black beans chickpeas, kidney beans, lentils, cauliflower or nuts
#
# 87
# What can be used to replace pork ribs?
# If you do not have pork ribs pork chops, or pork belly
#
# 88
# What can be used to replace smokey bacon?
# If you do not have smokey bacon liquid smoke, smoked paprila, veggie bacon, dark beer or blackstrap moasses
#
# 89
# What can be used to replace pork belly?
# If you do not have pork belly pork chops or pork ribs
#
# 90
# What can be used to replace dried chili?
# If you do not have dried chili serrano pepper, cayenne pepper, pequin chili or jalapeno
#
# 91
# What can be used to replace cumin?
# If you do not have cumin ground coriander, caraway seeds, chili powder, taco seasoning, curry powder or garam masala
#
# 92
# What can be used to replace oregano?
# If you do not have oregano mint, parsley or poultry seasoning
#
# 93
# What can be used to replace beans?
# If you do not have beans tofu, sourgram, cauliflowder florets, tempeh, quinoa, peas or eggplant
#
# 94
# What can be used to replace long grain rice?
# If you do not have long grain rice white rice, brown rice or egg friend rice
#
# 95
# What can be used to replace star anise?
# If you do not have star anise allspice, chinese five spice powder or chili powder
#
# 96
# What can be used to replace spring onions?
# If you do not have spring onions challots, green onions, red onions or celery
#
# 97
# What can be used to replace miso paste?
# If you do not have miso paste soy sauce, salt, tahini or vegetable stock
#
# 98
# What can be used to replace mirin?
# If you do not have mirin dry sherry or sweet masala wine
#
# 99
# What can be used to replace soy sauce?
# If you do not have soy sauce tamari, worcestershire sauce, coconut aminos, miso paste or maggi seasoning
#
# 100
# What can be used to replace shiitake mushrooms?
# If you do not have shiitake mushrooms portobello mushrooms, crimini mushrooms or porcini mushrooms
#
# 101
# What can be used to replace baby spinach?
# If you do not have baby spinach rocket, spinach, watercress or beet greens
#
# 102
# What can be used to replace white pepper?
# If you do not have white pepper ground giner, ground mustard or pink peppercorns
#
# 103
# What can be used to replace furikake?
# If you do not have furikake crumbled nori seaweed, sesame seeds or togarashi
#
# 104
# What can be used to replace pasta?
# If you do not have pasta spaghetti, eggplant lasagna, cabbage noodles, sprouts or onion noodles
#
# 105
# What can be used to replace curry leaves?
# If you do not have curry leaves lime zest, bay leves, basil leaves, lemon zest or daun salam leaves
#
# 106
# What can be used to replace asafoetida?
# If you do not have asafoetida garlic powder, garlic cloves or
#
# 107
# What can be used to replace peanuts?
# If you do not have peanuts beans, pretzels, seeds, tahini, sunflower seeds or almonds
#
# 108
# What can be used to replace almonds?
# If you do not have almonds breadcrumbs, ground rice, semolina or polenta
#
# 109
# What can be used to replace sesame seeds?
# If you do not have sesame seeds poppy seeds or hemp seeds
#
# 110
# What can be used to replace golden raisins?
# If you do not have golden raisins pitted dates, prines or dried cranberries
#
# 111
# What can be used to replace cashew nuts?
# If you do not have cashew nuts pine nuts, almonds, walknuts, hazelnuts or sunflower seeds
#
# 112
# What can be used to replace green chili?
# If you do not have green chili banana pepper, anaheim pepper, poblano pepper, jalapeno, serrano or chilli powder
#
# 113
# What can be used to replace rib roast?
# If you do not have rib roast prok belly or pork chops,
#
# 114
# What can be used to replace kosher salt?
# If you do not have kosher salt sea saly, brine or coarse himalayan pink salt
#
# 115
# What can be used to replace worcestershire sauce?
# If you do not have worcestershire sauce soy sauce, miso paste, soy sauce and ketcup r soy cause and apple sauce
#
# 116
# What can be used to replace liquid smoke?
# If you do not have liquid smoke smoked paprika, smoke tea or chipotle powder
#
# 117
# What can be used to replace beef broth?
# If you do not have beef broth vegetable broth, bouillon cubes, soy sauce or mushroom broth
#
# 118
# What can be used to replace mustard powder?
# If you do not have mustard powder tumeri powder, wasabi powder or mustard seed
#
# 119
# What can be used to replace coriander powder?
# If you do not have coriander powder cumin, garam masala, curry powder or caraway
#
# 120
# What can be used to replace onion powder?
# If you do not have onion powder onion flakes, minced onion, fresh onion or garlc powder
#
# 121
# What can be used to replace bay leaves?
# If you do not have bay leaves dried thyme or oregano
#
# 122
# What can be used to replace dried thyme?
# If you do not have dried thyme oregano, marjoram, rosemary, savoury or basil
#
# 123
# What can be used to replace rosemary?
# If you do not have rosemary thyme, tarragon or savory
#
# 124
# What can be used to replace yellow pepper?
# If you do not have yellow pepper red pepper, green pepper, orange bell peppers
#
# 125
# What can be used to replace chorizo?
# If you do not have chorizo smoked paprika or bacon rind
#
# 126
# What can be used to replace cannellini beans?
# If you do not have cannellini beans red kideny beans, great northen beans or navy beans
#
# 127
# What can be used to replace italian seasoniong?
# If you do not have italian seasoniong basil, marjoram, oregano, rosemary or thyme
#
# 128
# What can be used to replace garlic salt?
# If you do not have garlic salt garlic powder, kosher salt, garlic cloves or garlic powder and salt
#
# 129
# What can be used to replace pepe pasta?
# If you do not have pepe pasta arugula or kale
#
# 130
# What can be used to replace parmesan cheese?
# If you do not have parmesan cheese gran padano or american grana, dry jack or pecorino
#
# 131
# What can be used to replace spinach?
# If you do not have spinach argula or kale
#
# 132
# What can be used to replace ricotta?
# If you do not have ricotta goats cheese, cottage cheese, sour cream, cream cheese or queso fresco
#
# 133
# What can be used to replace boiled ham?
# If you do not have boiled ham candian bacon or gammon
#
# 134
# What can be used to replace spice rub?
# If you do not have spice rub BBQ seasoning, italian seasoning or allspiace
#
# 135
# What can be used to replace cayenne pepper?
# If you do not have cayenne pepper chili powder, paprika or red chili flakes
#
# 136
# What can be used to replace peanut sauce?
# If you do not have peanut sauce almond butter or cashew butter
#
# 137
# What can be used to replace jalapeno pepper?
# If you do not have jalapeno pepper serrano pepper, fresno pepper, anaheim pepper pr pblano pepper
#
# 138
# What can be used to replace chicken broth?
# If you do not have chicken broth beef stock, vegetable stock or lamb stock
#
# 139
# What can be used to replace peanut butter?
# If you do not have peanut butter sunflower seed butter, cookie butter, or coconut butter
#
# 140
# What can be used to replace coconut milk?
# If you do not have coconut milk soy milk, almond milk, oat milk or rice milk
#
# 141
# What can be used to replace figs?
# If you do not have figs raisins, prines or dried apriocots
#
# 142
# What can be used to replace honey?
# If you do not have honey date paste, agave nectar, maple syrup or brown rice sugar
#
# 143
# What can be used to replace apple vinegar?
# If you do not have apple vinegar rice vinegar, red wine vinegar, lemon juice or champagne vinegar
#
# 144
# What can be used to replace deli ham?
# If you do not have deli ham roasted chicken or canned salmon
#
# 145
# What can be used to replace swiss cheese?
# If you do not have swiss cheese fontina cheese, cheddar cheese or mozzerella cheese
#
# 146
# What can be used to replace milk yoghurt?
# If you do not have milk yoghurt buttermilk, or sour cream
#
# 147
# What can be used to replace confectioners sugar?
# If you do not have confectioners sugar granulated sugar or brown sugar
#
# 148
# What can be used to replace low fat greek yogurt?
# If you do not have low fat greek yogurt buttermilk, tofu, cottage cheese or sour cream
#
# 149
# What can be used to replace butternut squash?
# If you do not have butternut squash buttercup squash, pupkin, carrots or acorn squash
#
# 150
# What can be used to replace chili flakes?
# If you do not have chili flakes cayenne pepper, black cardamon or fennel seeds
#
# 151
# What can be used to replace broccoli?
# If you do not have broccoli kale, leafy greens, asparagus, or baby spinach leaves
#
# 152
# What can be used to replace gorgonzola?
# If you do not have gorgonzola roquefort, stilon, danish blue or creamy blue cheese
#
# 153
# What can be used to replace leek?
# If you do not have leek green onions, red onions, challots or celery
#
# 154
# What can be used to replace fennel?
# If you do not have fennel anise seeds, cumin seeds, caraway seeds or dill
#
# 155
# What can be used to replace acord squash?
# If you do not have acord squash butternut squash or pumpkin squash
#
# 156
# What can be used to replace sea slat flakes?
# If you do not have sea slat flakes table salt or maldon salt
#
# 157
# What can be used to replace tarragon?
# If you do not have tarragon dill, basil or marjoram
#
# 158
# What can be used to replace hazelnuts?
# If you do not have hazelnuts walnuts, macadamia nuts or almonds
#
# 159
# What can be used to replace mature cheddar cheese?
# If you do not have mature cheddar cheese gouda or parmesan cheese
#
# 160
# What can be used to replace tilapia?
# If you do not have tilapia catfish, striped bass, red snapper or rainbow trout
#
# 161
# What can be used to replace panko breadcrumbs?
# If you do not have panko breadcrumbs regular breadcrumbs, cracker crumbs, matzo meal, crushed cornflakes or dry stuffing mix
#
# 162
# What can be used to replace parmesan cheese?
# If you do not have parmesan cheese grana padano, piave cheese or pecorino
#
# 163
# What can be used to replace paprika?
# If you do not have paprika cayenne pepper, chili powder, chili flakes or red chili
#
# 164
# What can be used to replace cream cheese?
# If you do not have cream cheese cottage cheese, mascarphone, tofu, ricotta cheese or sour cream
#
# 165
# What can be used to replace hot sauce?
# If you do not have hot sauce chili powder, chili flakes, harissa, or curry paste
#
# 166
# What can be used to replace tortilla wraps?
# If you do not have tortilla wraps lettice wraps or pita bread
#
# 167
# What can be used to replace marrow?
# If you do not have marrow courgette or squash
#
# 168
# What can be used to replace semolina?
# If you do not have semolina flour, bread flour or whole wheat flour
#
# 169
# What can be used to replace northen beans?
# If you do not have northen beans navy beans, cannellini beans or lima beans
#
# 170
# What can be used to replace dry mustard powder?
# If you do not have dry mustard powder dijon mustard or tumeric
#
# 171
# What can be used to replace ansjovis?
# If you do not have ansjovis shrimp, shrimp paste, capers or asian fish sauce
#
# 172
# What can be used to replace shallots?
# If you do not have shallots sweet onions, leeks, garlic scapes, red onions or green onions
#
# 173
# What can be used to replace tumeric?
# If you do not have tumeric ginger powder, cumin, saffron or annatto powder
#
# 174
# What can be used to replace galangal?
# If you do not have galangal fresh ginger or ginger powder
#
# 175
# What can be used to replace lemongrass?
# If you do not have lemongrass lemon grass, lemon juice, lime zest or lemon balm
#
# 176
# What can be used to replace dry yeast?
# If you do not have dry yeast equal parts lemon juice and baking soda
#
# 177
# What can be used to replace almonds?
# If you do not have almonds breadcrumbs, ground rice and polenta
#
# 178
# What can be used to replace aniseed?
# If you do not have aniseed star anise, fennel seed, teaspoon caraway seed or chopped tarragon
#
# 179
# What can be used to replace asparagus?
# If you do not have asparagus broccoli, celery, green beans or lettuce
#
# 180
# What can be used to replace jicama?
# If you do not have jicama daikon radish or jerusalem artichokes
#
# 181
# What can be used to replace red cabbage?
# If you do not have red cabbage white cabbage or napa cabbage
#
# 182
# What can be used to replace purple cabbage?
# If you do not have purple cabbage napa cabbage, breussels sprouts, bok choy and celery
#
# 183
# What can be used to replace lettuce?
# If you do not have lettuce spinach or parsley
#
# 184
# What can be used to replace blueberries?
# If you do not have blueberries acai berries, blackberries, huckleberries, raspberries or currents
#
# 185
# What can be used to replace mint?
# If you do not have mint peppermint or parsely
#
# 186
# What can be used to replace mine confit zest?
# If you do not have mine confit zest lemon zest or lime zest
#
# 187
# What can be used to replace chinese oyster sauce?
# If you do not have chinese oyster sauce soy sauce, hoisin sauce or fish sauce
#
# 188
# What can be used to replace apple cider vinegar?
# If you do not have apple cider vinegar red wine, white wine or sherry vinegar
#
# 189
# What can be used to replace saffron?
# If you do not have saffron turmeric or cumin
#
# 190
# What can be used to replace mussels?
# If you do not have mussels shrimp, prawns or clam
#
# 191
# What can be used to replace prawns?
# If you do not have prawns mussels, clam or shrimp
#
# 192
# What can be used to replace monkfish?
# If you do not have monkfish snapper, sea bass, halibut or sea scallops
#
# 193
# What can be used to replace squid?
# If you do not have squid prawns oe firm white fish
#
# 194
# What can be used to replace risotto rice?
# If you do not have risotto rice brown rice, sushi rice, basmati rice or quinoa
#
# 195
# What can be used to replace dry white wine?
# If you do not have dry white wine apple cider vinegar, chicken broth, white grape juice or ginger ale
#
# 196
# What can be used to replace chicken legs?
# If you do not have chicken legs chicke drumsticks or chicken thighs
#
# 197
# What can be used to replace cherry tomatoes?
# If you do not have cherry tomatoes olives, red pepper or canned tomatoes
#
# 198
# What can be used to replace capers?
# If you do not have capers green olives, anchovies or pickles
#
# 199
# What can be used to replace djion mustard?
# If you do not have djion mustard yellow mustard, honey mustard, wasabi or mayonnaise
#
# 200
# What can be used to replace beef bouillon?
# If you do not have beef bouillon chicken broth or vegetable stock
#
# 201
# What can be used to replace celery seeds?
# If you do not have celery seeds flat leaf parsley or dill seed
#
# 202
# What can be used to replace chickpeas?
# If you do not have chickpeas green peas, lentils, soybeans, mung beans or peanuts
#
# 203
# What can be used to replace lamb stock?
# If you do not have lamb stock chicken stock or vegetable stock
#
# 204
# What can be used to replace canned tomatoes?
# If you do not have canned tomatoes fresh tomatoes, sun dried tomatoes or red peppers
#
# 205
# What can be used to replace caramilk chocolate?
# If you do not have caramilk chocolate white chocolate, milk chocolate or dark chocolate
#
# 206
# What can be used to replace coca?
# If you do not have coca jackfruit seeds
#
# 207
# What can be used to replace garam masala?
# If you do not have garam masala curry powder, allspice powder or chaat powder
#
# 208
# What can be used to replace arbol chili powder?
# If you do not have arbol chili powder cayenne powder or generic chili powder
#
# 209
# What can be used to replace ghee?
# If you do not have ghee olive oil, coconut oil, canola oil, soybean oil, sunflower oil or butter
#
# 210
# What can be used to replace turkey tenderloin?
# If you do not have turkey tenderloin turkey breast fillets or turkey bacon
#
# 211
# What can be used to replace Egg noodles?
# If you do not have Egg noodles fettucine, ribbon pasta, linguine or brown / white rice
#
# 212
# What can be used to replace Chicken liver?
# If you do not have Chicken liver duck liver, turkey liver or goose liver
#
# 213
# What can be used to replace Chicken gizzard?
# If you do not have Chicken gizzard turkey gizzard or goose gizzard
#
# 214
# What can be used to replace Bell pepper?
# If you do not have Bell pepper anahiem peppers, Jalapenos, pimiento or zucchini
#
# 215
# What can be used to replace Small head wombok?
# If you do not have Small head wombok other cabbages such as red, white or napa cabbage
#
# 216
# What can be used to replace Oyster sauce?
# If you do not have Oyster sauce soy sauce, sweet soy sauce, hoisin sauce or plumb sauce
#
# 217
# What can be used to replace Calamansi?
# If you do not have Calamansi lemon and lime juices
#
# 218
# What can be used to replace Dry white wine?
# If you do not have Dry white wine white wine vinegar
#
# 219
# What can be used to replace Orange Roughy?
# If you do not have Orange Roughy perch, blackfish, flounder, sole, haddock or red snapper
#
# 220
# What can be used to replace Limes?
# If you do not have Limes orange, lemon or zest
#
# 221
# What can be used to replace Serrano peppers?
# If you do not have Serrano peppers jalapeno, habanero, cayenne, guero or poblano pepper
#
# 222
# What can be used to replace Avocado?
# If you do not have Avocado chai seeds or tree nuts
#
# 223
# What can be used to replace Honey?
# If you do not have Honey rice maly syrup, brown rice syrup, molasses, coconut syrup, maple syrup or golden syrup
#
# 224
# What can be used to replace Roma tomato?
# If you do not have Roma tomato polish paste, plum or oxheart tomatoes
#
# 225
# What can be used to replace Yellow rice?
# If you do not have Yellow rice white rice, brown rice, long grain rice or egg fried rice
#
# 226
# What can be used to replace Bisquick?
# If you do not have Bisquick 1 cup of all purpose flow mixed with 1 and a half teaspoons of baking powder, half a teaspoon or salt and one tablespoon of vegetable oil
#
# 227
# What can be used to replace Smoked paprika?
# If you do not have Smoked paprika hungarian paprika, sweer paprika, chipolatle chili or liquid smoke
#
# 228
# What can be used to replace split pigs feet?
# If you do not have split pigs feet ham hocks or ham shanks
#
# 229
# What can be used to replace chicken bouillon cube?
# If you do not have chicken bouillon cube chicken broth, dry white wine, poultry seasoning with water
#
# 230
# What can be used to replace butternut squash and beet noodles?
# If you do not have butternut squash and beet noodles cucumber noodles,carrot noodles, raddish noodles, summer squash noodles, spiralized kohlrabi, sweet potato noodles or zucchini noodles
#
# 231
# What can be used to replace bosc pears?
# If you do not have bosc pears asian pears, apples, quinces or figs
#
# 232
# What can be used to replace pecans?
# If you do not have pecans hazelnuts, pistachios, macadamia nuts, brazil nuts, walnuts or pecan oil
#
# 233
# What can be used to replace canola oil?
# If you do not have canola oil grapeseed oil, vegetable oil or sunflower oil
#
# 234
# What can be used to replace vodka?
# If you do not have vodka water, apple cide vinegar or white grae juice mixed with lime juice  aquavit, tequila or white rum
#
# 235
# What can be used to replace cane sugar?
# If you do not have cane sugar honey, maple syrup, applesauce, caster sugar, brown sugar, raw sugar, powdered sugar, molasses or corn syrup
#
# 236
# What can be used to replace apple cider vinegar?
# If you do not have apple cider vinegar red or white wine vinegar, rice vinegar, sherry vinegar, champagne vinegar or lemon juice
#
# 237
# What can be used to replace jasmine rice?
# If you do not have jasmine rice basmati rice or long-grain rice
#
# 238
# What can be used to replace ground cinnamon?
# If you do not have ground cinnamon nutmeg, cloves, allspice or apple pie spice
#
# 239
# What can be used to replace canned plum tomatoes?
# If you do not have canned plum tomatoes regular tomatoes and tomato paste, fresh tomatoes and canned whole tomatoes or sun-dried tomatoe
#
# 240
# What can be used to replace can of tomato sauce?
# If you do not have can of tomato sauce ketchup, tomato soup or tomato paste
#
# 241
# What can be used to replace can of tomato sauce?
# If you do not have can of tomato sauce asian pears, apples, quinces or figs
#
# 242
# What can be used to replace coconut cream?
# If you do not have coconut cream coconut milk, whipping cream, nut butter, tahini, greek yogurt or creamy tomato sauce
#
# 243
# What can be used to replace sugar?
# If you do not have sugar honey, maple syrup, applesauce, molasses, cane sugar or brown sugar
#
# 244
# What can be used to replace all-purpose flour?
# If you do not have all-purpose flour chickpea flour, rice flour, almond flour, buckwheat flour or a mixture of bread flour with cake flour
#
# 245
# What can be used to replace baking powder?
# If you do not have baking powder buttermilk, plain yogurt, molasses, cream of tartar, sour milk, vinegar, lemon juice, baking soda, self-rising flour or whipped egg whites
#
# 246
# What can be used to replace baking soda?
# If you do not have baking soda baking powder, potassium bicarbonate and salt, self-rising flour or baker's ammonia
#
# 247
# What can be used to replace grated nutmeg?
# If you do not have grated nutmeg ground nutmeg, mace, garam masala, allspice, cinamon, pumpkin pie spice, appke pie spice, ginger or cloves
#
# 248
# What can be used to replace ginger powder?
# If you do not have ginger powder ground allspice, ground cinnamon, ground mace or ground nutmeg
#
# 249
# What can be used to replace granulated sugar?
# If you do not have granulated sugar honey, maple syrup, applesauce, caster sugar, brown sugar, powdered sugar, molasses or corn syrup
#
# 250
# What can be used to replace packed light brown sugar?
# If you do not have packed light brown sugar white sugar and molasses, honey, white sugar and maple syrup, coconut sugar, maple syryp, agave nectar or plain white sugar
#
# 251
# What can be used to replace canned unsweetened pumpkin puree?
# If you do not have canned unsweetened pumpkin puree frozen butternut squash, sweet potatoes, roasted acorn squash or fresh pumpkin puree
#
# 252
# What can be used to replace cranberries?
# If you do not have cranberries apricots, apples, cherries, raspberries blueberries or currants
#
# 253
# What can be used to replace maple syrup?
# If you do not have maple syrup honey, brown sugar, white sugar, molasses orcorn syrup
#
# 254
# What can be used to replace turkey neck?
# If you do not have turkey neck chicken quarters
#
# 255
# What can be used to replace celery sticks?
# If you do not have celery sticks fennel, onion, scallions, carrots, shallots, garlic, chives or leeks
#
# 256
# What can be used to replace tamari?
# If you do not have tamari soy sauce, fish sauce, salt, miso paste, teriyaki sauce or maggi seasoning
#
# 257
# What can be used to replace walnuts?
# If you do not have walnuts almonds, cashews, filberst, brazil nuts or macadamia nuts
#
# 258
# What can be used to replace whole milk?
# If you do not have whole milk semi-skimmed milk, double cream, yogurt, sour cream, soy milk or coconut milk
#
# 259
# What can be used to replace red currant?
# If you do not have red currant raisins, dried dates, dried prunes, dried cherries, cranberries or jujube
#
# 260
# What can be used to replace raspberry jelly?
# If you do not have raspberry jelly strawberry jelly, cranberry jelly or red currants
#
# 261
# What can be used to replace bittersweet chocolate?
# If you do not have bittersweet chocolate unsweetened baking chocolate and sugar or semisweet chocolate with cocoa powder
#
# 262
# What can be used to replace unsweetened cocoa powder?
# If you do not have unsweetened cocoa powder melted unsweetened baking chocolate, dutch-processed cocoa or carob powder
#
# 263
# What can be used to replace buttermilk?
# If you do not have buttermilk milk and vinegar, milk and lemon juice, milk and cream of tartar, sour cream and water, plain yogurt and water or plain kefir
#
# 264
# What can be used to replace semisweet chocolate chips?
# If you do not have semisweet chocolate chips bittersweet baking chocolate, unsweetened cocoa powder, or unsweetened baking chocolate
#
# 265
# What can be used to replace cream of tartar?
# If you do not have cream of tartar lemon juice, white vinegar, baking powder, buttermilk or yogurt
#
# 266
# What can be used to replace egg whites?
# If you do not have egg whites aquafaba, ground flax seeds and water, agar powder and water or chia seeds and water
#
# 267
# What can be used to replace dark brown sugar?
# If you do not have dark brown sugar white sugar and molasses, honey, white sugar and maple syrup, coconut sugar, maple syryp, agave nectar or plain white sugar
#
# 268
# What can be used to replace vegetable oil?
# If you do not have vegetable oil canola oil, sunflower oil, peanut oil or grapeseed oil
#
# 269
# What can be used to replace ground nutmeg?
# If you do not have ground nutmeg grated nutmeg, mace, garam masala, allspice, cinamon, pumpkin pie spice, appke pie spice, ginger or cloves
#
# 270
# What can be used to replace old-fashioned rolled-oats?
# If you do not have old-fashioned rolled-oats qionoa flakes, stell-cut oats or instant oats
#
# 271
# What can be used to replace raisins?
# If you do not have raisins dried currants, dried cherries, dried cranberries, dried prunes, dried sates, dried apricot or dried pineapple
#
# 272
# What can be used to replace vanilla?
# If you do not have vanilla maple syrup, almond extract, bourbon, instant coffee, expresso powder or citrus zest
#
# 273
# What can be used to replace lemon zest?
# If you do not have lemon zest lemon extract, lemon juice, another citrus zest or lemon peel
#
# 274
# What can be used to replace parsnips?
# If you do not have parsnips turnips, celery root, carrots, salsify, sweet potatoes or parsley root
#
# 275
# What can be used to replace thyme leaves?
# If you do not have thyme leaves oregano, majoram, basil, savory, poultry seasoning, italian seasoning, za'taar or herbes de provence
#
# 276
# What can be used to replace white bread?
# If you do not have white bread oopsie bread, ezekiel bread, corn tortillas or rye bread
#
# 277
# What can be used to replace canned cannellini beans?
# If you do not have canned cannellini beans red kidney beans, great northern beans, navy beans, baby lima beans, butter beans, garbanzo beans, borlotti beans or black beans
#
# 278
# What can be used to replace baby lima beans?
# If you do not have baby lima beans fava beans, red kidney beans or white kidney beans
#
# 279
# What can be used to replace large egg?
# If you do not have large egg any other size of egg
#
# 280
# What can be used to replace powdered gelatin?
# If you do not have powdered gelatin agar agar powder, pectin powder, carrageean or guar gum
#
# 281
# What can be used to replace ground beef?
# If you do not have ground beef mushrooms, ground poultry, textured vegetable protein, lentils, tempeh, tofu, seitan or beans
#
# 282
# What can be used to replace prociutto?
# If you do not have prociutto ham, bacon, pancetta, capiola or spanish serrano ham
#
# 283
# What can be used to replace parsley leaves?
# If you do not have parsley leaves cilantro, celery leaves, carrot greens, chives or chervil
#
# 284
# What can be used to replace crsuhed tomatoes?
# If you do not have crsuhed tomatoes fresh tomatoes, diced tomatoes, tomato paste, tomato puree, whole peeled tomatoes or pasta sauce
#
# 285
# What can be used to replace cooking wine?
# If you do not have cooking wine white grape juice and apple juice, apple cider, cranberry juice, ginger ale, white wine vinegar, red wine vingear, lemon juice, chicken broth or vegetable broth
#
# 286
# What can be used to replace spaghetti?
# If you do not have spaghetti vermicelli, angel hair pasta or rice stick noodles
#
# 287
# What can be used to replace red potatoes?
# If you do not have red potatoes yukon gold potatoes, white potatoes, yellow potatoes or russet potato
#
# 288
# What can be used to replace chicken breasts?
# If you do not have chicken breasts chicken cacciatora, shrimp aragonate, grilled scallops, seared duck breasts or roast trukey breasts
#
# 289
# What can be used to replace marsala red wine?
# If you do not have marsala red wine madeira, fortified wine, dru sherry, sherry wine and sweet vermouth, amontillado wine and pedro ximenez, port, white grape juice with brandy, non-fortified wine, pinot noir or dry white wine
#
# 290
# What can be used to replace unflavoured gelatin?
# If you do not have unflavoured gelatin kudzu, pectin and sugar, arrowroot or agar agar
#
# 291
# What can be used to replace porcini mushrooms?
# If you do not have porcini mushrooms shiitake mushrooms, dried reconstituted shiitake mushrooms, mixed mushrooms or fresh button mushrooms
#
# 292
# What can be used to replace cremini mushrooms?
# If you do not have cremini mushrooms white button mushrooms, portobello mushrooms, shiitake mushrooms or aubergine
#
# 293
# What can be used to replace white mushrooms?
# If you do not have white mushrooms courgette, sun dried toamtoes, aubergine, garbanzo beans, russel potatoes, tofu or onions
#
# 294
# What can be used to replace pasta sauce?
# If you do not have pasta sauce toamato paste, ketchup or tomato soup
#
# 295
# What can be used to replace lasagna noodles?
# If you do not have lasagna noodles macaroni with tomato sauce or flat-sliced courgette
#
# 296
# What can be used to replace mozzarella cheese?
# If you do not have mozzarella cheese white cheddar cheese, provolone, gouda, parmesan, ricotta or feta cheese
#
# 297
# What can be used to replace baking spray?
# If you do not have baking spray butter or lard
#
# 298
# What can be used to replace gruyere cheese?
# If you do not have gruyere cheese comte cheese, beaufort cheese, jalsberg cheese, emmentaler cheese, fontina and parmesan cheese, maasdam and edam cheese or raclette cheese
#
# 299
# What can be used to replace cherries?
# If you do not have cherries canned cherries, fresh plums, fresh apricots or fresh nectarines
#
# 300
# What can be used to replace yellow onions?
# If you do not have yellow onions red onion or white onion, ricotta or feta cheese
#
# 301
# What can be used to replace mixed mushrooms?
# If you do not have mixed mushrooms courgette, sun dried toamtoes, aubergine, garbanzo beans, russel potatoes, tofu or onions
#
# 302
# What can be used to replace dried white beans?
# If you do not have dried white beans dried cannellini beans, dried navy beans, dried red beans or dried pinto beans
#
# 303
# What can be used to replace canned peeled tomateos?
# If you do not have canned peeled tomateos crushed tomatoes, diced tomatoes or fresh tomatoes
#
# 304
# What can be used to replace swiss chard?
# If you do not have swiss chard mature spinach, mustard greens, kale or large bok choy
#
# 305
# What can be used to replace kale?
# If you do not have kale collard greens, english spinach, baby spinach, swiss chard, mustard greens, chinese broccoli, broccoli raab or turnip
#
# 306
# What can be used to replace almond flour?
# If you do not have almond flour wheat flour, all-purpose flour, cashew flour, macadamia flour, sunflower seed flour, oat flour or a combination of tapioca flour with coconut flour
#
# 307
# What can be used to replace almond extract?
# If you do not have almond extract vanilla extract or almond flavoured liquor
#
# 308
# What can be used to replace rose water?
# If you do not have rose water rose essence, jamaica flower water,orange flower water, vanilla extract, almond extract, lavender, lemon juice or cardamom
#
# 309
# What can be used to replace food colouring?
# If you do not have food colouring liquid chlorophyll, matcha powder, spirulina powder, whatgrass juice or parsley juice
#
# 310
# What can be used to replace marzipan?
# If you do not have marzipan almond paste
#
# 311
# What can be used to replace dried black beans?
# If you do not have dried black beans kidney beans, pinto beans, lentils, soyebans, chickpeas or peas
#
# 312
# What can be used to replace lime juice?
# If you do not have lime juice lemon juice, lime zest, orange juice or white wine vinegar
#
# 313
# What can be used to replace red bell pepper?
# If you do not have red bell pepper poblano peppers, anaheim peppers, jalapeños, sichuan peppers, cubanelle or red, yellow or orange peppers
#
# 314
# What can be used to replace cocoa powder?
# If you do not have cocoa powder a chocolate bar, chocolate chips, chocolate coverture, hot chocolate drink powder or carob powder
#
# 315
# What can be used to replace agave syrup?
# If you do not have agave syrup honey, simple syrup, maple syrup, brown rice syrup, white sugar, corn syrup or any artificial sweeteners
#
# 316
# What can be used to replace nutella?
# If you do not have nutella any other chocolate spread or hazelnut and chocolate spread
#
# 317
# What can be used to replace maraschino cherries?
# If you do not have maraschino cherries fresh cherries, amarena cherries or luxardo maraschino cherries
#
# 318
# What can be used to replace maraschino cherry juice?
# If you do not have maraschino cherry juice cherry juice with sugar
#
# 319
# What can be used to replace greek yogurt?
# If you do not have greek yogurt plain yogurt, sour cream, buttermilk, cottage cheese or silken tofu
#
# 320
# What can be used to replace roasted chicken meat?
# If you do not have roasted chicken meat rotisserie chicken meat
#
# 321
# What can be used to replace old bay seasoning?
# If you do not have old bay seasoning instead you can make your own by combining 1 tablespoon celery salt, 3 whole bay leaves, 3/4 teaspoon brown mustard seeds, 1/2 teaspoon black peppercorns, 10 allspice berries, 10 whole cloves and 1/2 teaspoon paprika or use crab boil or pickling spice
#
# 322
# What can be used to replace unsalted butter?
# If you do not have unsalted butter shortening, vegetable oil or lard
#
# 323
# What can be used to replace butterscotch chips?
# If you do not have butterscotch chips caramel chips, chocolate chips or carob chips
#
# 324
# What can be used to replace sirloin steak?
# If you do not have sirloin steak ribeye steak, new York strip steaks, round steak or flank steak
#
# 325
# What can be used to replace dry mustard?
# If you do not have dry mustard dijon mustard or yellow mustard
#
# 326
# What can be used to replace white wine?
# If you do not have white wine apple cider vinegar, chicken broth, apple juice, grape juice, white wine vinegar or ginger ale
#
# 327
# What can be used to replace cauliflower?
# If you do not have cauliflower broccoli, courgette or lettuce
#
# 328
# What can be used to replace orange zest?
# If you do not have orange zest any other citrus fruit zest, fruit juice, fruit concentrate, pure extracts or vinegar
#
# 329
# What can be used to replace green bell pepper?
# If you do not have green bell pepper poblano peppers, anaheim peppers, jalapeños, sichuan peppers, pimientos, cubanelle, red bell peppers or yellow bell peppers
#
# 330
# What can be used to replace chipotle chillies?
# If you do not have chipotle chillies fresh jalapeños, serrano peppers or poblano peppers
#
# 331
# What can be used to replace chilli powder?
# If you do not have chilli powder paprika, cumin, garlic powder, onion powder, oregano or cayenne
#
# 332
# What can be used to replace ground coriander?
# If you do not have ground coriander cumin, caraway, garam masala or curry powder
#
# 333
# What can be used to replace ground cumin?
# If you do not have ground cumin ground coriander, caraway seeds, chilli powder, taco seasoning, curry powder, garam masala, paprika or fennel seeds
#
# 334
# What can be used to replace ground buffalo?
# If you do not have ground buffalo ground bison or ground beef
#
# 335
# What can be used to replace pinto beans?
# If you do not have pinto beans black beans, navy beans, borlotti beans, red beans, kidney beans, white beans or cannellini beans
#
# 336
# What can be used to replace masa harina flour?
# If you do not have masa harina flour corn meal, gritis, regular flour, ground corn tortillas, corn starch, fresh masa or masa preparada
#
# 337
# What can be used to replace green beans?
# If you do not have green beans nopalitos, thin asparagus stalks or wax beans
#
# 338
# What can be used to replace white flour?
# If you do not have white flour almond flour, coconut flour, quinoa flour, chickpea flour, brown rice flour, oat flour, spelt flour or buckwheat flour
#
# 339
# What can be used to replace cardamom?
# If you do not have cardamom cinnamon and cloves, cinnamon and nutmeg or allspice powder
#
# 340
# What can be used to replace caster sugar?
# If you do not have caster sugar granulated sugar
#
# 341
# What can be used to replace free-range eggs?
# If you do not have free-range eggs banana, flaxseed, chia seeds, applesauce or organic eggs
#
# 342
# What can be used to replace shortening?
# If you do not have shortening butter, coconut oil, margarine, lard, vegetable oil or vegan butter
#
# 343
# What can be used to replace vinegar?
# If you do not have vinegar lemon or lemon juice
#
# 344
# What can be used to replace mung beans?
# If you do not have mung beans snow peas or pigeon peas
#
# 345
# What can be used to replace hash browns?
# If you do not have hash browns cauliflower hash browns, keto has browns or fries
#
# 346
# What can be used to replace cream of chicken soup?
# If you do not have cream of chicken soup sour cream, yogurt, tomato sauce or eggs and milk
#
# 347
# What can be used to replace colby cheese?
# If you do not have colby cheese pata cabra cheese, fontina cheese, limburguer cheese or carciotta cheese
#
# 348
# What can be used to replace sherry?
# If you do not have sherry white wine vinegar, apple cider vinegar, sherry vinegar or port wine
#
# 349
# What can be used to replace sesame oil?
# If you do not have sesame oil perilla oil, walnut oil, oilve oil, canola oil, avocado oil, tahini or roasted sesame seed
#
# 350
# What can be used to replace garlic sauce?
# If you do not have garlic sauce harissa sauce, sriracha, ketchup with garlic or red pepper flakes
#
# 351
# What can be used to replace red pepper flakes?
# If you do not have red pepper flakes dried peppers, ground cayenne pepper or chilli powder
#
# 352
# What can be used to replace dill?
# If you do not have dill fennel, thyme, rosemary, parsley, chevil, basil or tarragon
#
# 353
# What can be used to replace smoked salmon?
# If you do not have smoked salmon smked mackerel, sardines, or pink snapper
#
# 354
# What can be used to replace arborio rice?
# If you do not have arborio rice pearled barley, basmati rice, brown rice, carnaroli rice, sushi rice, quinoa or bulgur wheat
#
# 355
# What can be used to replace marinara sauce?
# If you do not have marinara sauce tomato sauce mixed with water
#
# 356
# What can be used to replace baby green peas?
# If you do not have baby green peas black-eyed peas, lima beans or fresh cranberry beans
#
# 357
# What can be used to replace bread crumbs?
# If you do not have bread crumbs almonds, walnuts, chia seeds or flax seeds
#
# 358
# What can be used to replace flour tortillas?
# If you do not have flour tortillas corn tortillas, grain-free tortillas, lettuce wraps or spinach wraps
#
# 359
# What can be used to replace chillies?
# If you do not have chillies red bell pepper flakes or smoked paprika
#
# 360
# What can be used to replace guacamole?
# If you do not have guacamole nut butter, pesto, edamame beans, hummus or mockamole
#
# 361
# What can be used to replace refried beans?
# If you do not have refried beans chilli beans, rattlesnake beans, red kidney beans or cranberry beans
#
# 362
# What can be used to replace angel food cake mix?
# If you do not have angel food cake mix sponge cake mix
#
# 363
# What can be used to replace milkfish?
# If you do not have milkfish mullet fish
#
# 364
# What can be used to replace calamansi juice?
# If you do not have calamansi juice lime juice, orange juice, vinegar, citric acid, lemon zest, white wine, lemon extract or cream of tartar
#
# 365
# What can be used to replace pickles?
# If you do not have pickles chopped dill pickles, freen olives, capers, green bell peppers, celery or cucumbers
#
# 366
# What can be used to replace eggplant?
# If you do not have eggplant okra, zuchinni, mushrooms, summer squash or root vegetables
#
# 367
# What can be used to replace grapes?
# If you do not have grapes baby kiwi, mayhaw berries, white mulberries or elderberry
#
# 368
# What can be used to replace pork?
# If you do not have pork chicken or tempeh
#
# 369
# What can be used to replace annatto powder?
# If you do not have annatto powder hibiscus powder, tumeric powder, nutmeg, beet powder and paprika
#
# 370
# What can be used to replace kinchay?
# If you do not have kinchay parsley, basil or herb mixtures

# %%
# Utensils Descriptions dataset

# variable
tempText = ""

# read file
file = open(path+"UtensilsDescriptionCleaned.txt", "r")
line = file.read()

# prepare each line
tempText += line

# gesplit temporary texdt tempText into tokens
tokens = tempText.split(':')

# keyword and answer
keyword = ""
answer = ""

# index used when looping through tokens
index = 0
# index used when inserting data into dataset array
datasetIndex = 0

# utensilsDescriptionData is used to collect data
utensilsDescriptionData = []

# loop thorugh tokens
for token in tokens:

  # line is contains keyword, product to be replaced
  if index%2==0:
    token = token.replace("'","")
    token = regex.sub(' ', token)
    token = token.strip()
    keyword = token
    question = "What is "+keyword+"?"
    # print(question)

  # line contains alternative products
  elif index%2!=0:
    #answer = token.replace(", do you have any of these ingredients?","")
    answer = regex.sub(' ', token)
    answer = answer.strip()
    answer = answer
    text = keyword+" is "+answer
    # print(text)

  # add question and text to the dataset
  if index>0 and index%2!=0:
    utensilsDescriptionData.append({"question":question,"context":text})
    datasetIndex = datasetIndex + 1

  # increase index
  index = index+ 1

# global alternativeProducts
utensilsDescription = pd.DataFrame(utensilsDescriptionData)

# print utensilsDescription
for i in range (len(utensilsDescription)):
    question = utensilsDescription["question"][i]
    context = utensilsDescription["context"][i]
    print(i+1)
    print(question)
    print(context)
    print("")
# Out:
# 1
# What is bowl?
# bowl is a cooking container that is usually larger than a cup and kept in a cupboard in the kitchen, it is typically made from glass, ceramic, plastic.
#
# 2
# What is spoon?
# spoon is an eating or cooking utensil consisting of a small shallow bowl with a relatively long handle made from metal, plastic, wood it is usually kept in the kitchen, in drawer.
#
# 3
# What is sieve?
# sieve is a metal or plastic device with meshes or perforations through which finer particles of a mixture are sifted, it is usually kept in a kitchen and stored in a cupboard.
#
# 4
# What is pan?
# pan is a shallow and open cooking container made from metal, it is usually found in a kitchen and stored in a cupboard.
#
# 5
# What is baking tray?
# baking tray is a metal rectangular sheet with a rolled edge used for baking, it is usually found in a kitchen inside a cupboard or draw.
#
# 6
# What is whisk?
# whisk is a metal or plastic wire utensil used for beating food by hand and is usually found in a kitchen inside a drawer.
#
# 7
# What is oven?
# oven is a cooking chamber used for baking, heating, or drying and is usually found in a kitchen.
#
# 8
# What is cellophane?
# cellophane is thin transparent plastic sheets used to package or cover food items, it is usually kept in a kitchen inside a drawer or cupboard.
#
# 9
# What is tea towel?
# tea towel is a fabric cloth used for drying dishes, it is typically found in a kitchen or airing cupboard.
#
# 10
# What is frying pan?
# frying pan is an open metal container with a handle that is used for frying foods, it is usually found in a kitchen inside a cupboard.
#
# 11
# What is kettle?
# kettle is a metal or plastic vessel used for boiling liquids, it is usually found in a kitchen on a tabletop or inside a cupboard
#
# 12
# What is kitchen knife?
# kitchen knife is a cutting instrument consisting of a sharp blade fastened to a handle, it is usually found in a kitchen inside a draw.
#
# 13
# What is saucepan?
# saucepan is a small deep metal cooking pan with a handle and is usually kept in a kitchen cupboard.
#
# 14
# What is greaseproof paper?
# greaseproof paper is a heavy stiff waxed paper used in cooking and baking to prevent food from sticking to cooking trays and is usually kept inside a kitchen drawer.
#
# 15
# What is cup?
# cup is a ceramic, porcelain or glass bowl-shaped drinking vessel usually kept in a kitchen cupboard.
#
# 16
# What is measuring jug?
# measuring jug is a plastic or glass cup that has markings for measuring liquids when cooking, it is usually kept inside a kitchen cupboard.
#
# 17
# What is dinner plate?
# dinner plate is a ceramic large plate usually 10 inches in diameter used for the main course of a meal, it is usually kept in a kitchen cupboard.
#
# 18
# What is rolling pin?
# rolling pin is a long wooden or plastic cylinder for rolling out dough, it is usually kept in a kitchen drawer.
#
# 19
# What is food processor?
# food processor is an electric kitchen appliance with a set of interchangeable blades revolving inside a container, it is usually kept in a kitchen cupboard.
#
# 20
# What is fluted flan tin?
# fluted flan tin is a metal cooking tin with a removable base, usually found in a kitchen drawer
#
# 21
# What is dinner fork?
# dinner fork is a large metal fork with 3 or 4 times, it is usually found in a kitchen drawer.
#
# 22
# What is pastry brush?
# pastry brush is also known as a basting brush, it is a wooden or plastic cooking utensil used to spread butter, oil or glaze on food, it is usually kept in a kitchen  drawer.
#
# 23
# What is round bladed knife?
# round bladed knife is also known as a butter knife is a non-sharp plastic or metal knife used to mix the butter chunks, it is usually found in a kitchen drawer.
#
# 24
# What is fridge?
# fridge is an appliance for keeping food or other items cool, it is usually found in a kitchen or utility room.
#
# 25
# What is food bag?
# food bag is a plastic sealable sleeve for preserving food items, it is usually kept in a kitchen cupboard.
#
# 26
# What is casserole dish?
# casserole dish is a large and deep, glass or ceramic cooking bowl, it is usually kept in a kitchen cupboard.
#
# 27
# What is teaspoon?
# teaspoon is a small spoon that is used especially for eating soft foods and stirring beverages and that holds about one third of a tablespoon, it is usually stored in a kitchen drawer.
#
# 28
# What is mixing bowl?
# mixing bowl is a large ceramic or plastic bowl used in cooking for mixing ingredients, it is usually stored in a kitchen cupboard.
#
# 29
# What is wooden spoon?
# wooden spoon is a large wooden spoon for stirring ingredients, it is usually stored in a kitchen drawer.
#
# 30
# What is chopsticks?
# chopsticks is a pair of slender plastic or wooden sticks held between thumb and fingers and used chiefly in Asian countries to lift food to the mouth, they are usually stored in a kitchen drawer.
#
# 31
# What is colander?
# colander is a perforated plastic or metal cylinder for washing or draining food, it is usually stored in a kitchen cupboard.
#
# 32
# What is filleting knife?
# filleting knife is a blunt metal concave knife or a flexible wire tool used to flesh a skin or hide, it is usually stored in a kitchen drawer.
#
# 33
# What is fish slice?
# fish slice is a metal or plastic kitchen tool that has a handle which is bent upward, and a wide, thin blade used for lifting and turning foods on a hot surface, it is usually stored in a kitchen drawer.
#
# 34
# What is bottle opener?
# bottle opener is a tool used to remove metal tops from some bottles, it is usually stored in a kitchen draw.
#
# 35
# What is dessert spoon?
# dessert spoon is a spoon intermediate in size between a teaspoon and a tablespoon for eating dessert, it is usually stored in a kitchen draw.
#
# 36
# What is can opener?
# can opener is a device that is used to open cans of food, it is usually stored in a kitchen draw or cupboard.
#
# 37
# What is bread knife?
# bread knife is a knife with a long blade that has a serrated or scalloped edge, it is usually stored in a kitchen drawer.
#
# 38
# What is dinner knife?
# dinner knife is a large table knife usually with a steel or silver blade and a handle, it is usually stored in a kitchen drawer.
#
# 39
# What is ladle?
# ladle is a deep-bowled long-handled spoon used especially for dipping up and conveying liquids, it is typically stored in a kitchen cupboard.
#
# 40
# What is masher?
# masher is a utensil for mashing cooked, raw or boiled food, it is usually stored in a kitchen draw or cupboard.
#
# 41
# What is peeler?
# peeler is a metal blade with a slot with a sharp edge attached to a handle, used to remove the outer layer (the skin or peel) of some vegetables such as potatoes, broccoli stalks, and carrots, and fruits such as apples and pears
#
# 42
# What is pizza cutter?
# pizza cutter is also known as a roller blade or a pizza wheel is a round bladed utensil that is used to cut pizzas, it is usually kept in the kitchen inside a draw.
#
# 43
# What is serving spoon?
# serving spoon is a large spoon or ladle used to serve out individual portions of food, it is usually kept in a kitchen drawer.
#
# 44
# What is soup spoon?
# soup spoon is soup spoon is a type of spoon with a large or rounded bowl, used for consuming soup, it is usually stored in a kitchen drawer.
#
# 45
# What is tongs?
# tongs is type of metal or plastic tool used to grip and lift objects instead of holding them directly with hands, they are usually stored in a kitchen drawer.
#
# 46
# What is kitchen scissors?
# kitchen scissors is scissors that are used for cutting and trimming foods such as meats, they are usually stored in a kitchen drawer.
#
# 47
# What is mason jar?
# mason jar is jars that have a two-part top, a lid with a rubber ring on the underside, which creates a vacuum seal and an outer band with screw threads that are reusable. They are usually stored in a pantry or kitchen cupboard.
#
# 48
# What is food blender?
# food blender is a machine that reduces solid food to a liquid or puree using rotating blades, they are usually stored in a kitchen cupboard.
#
# 49
# What is bottle?
# bottle is a glass container for liquids and preserves, they are usually stored in a pantry or kitchen cupboard.
#
# 50
# What is paring knife?
# paring knife is a small sharp knife with a short blade, it is usually kept in a kitchen drawer.
#
# 51
# What is garlic press?
# garlic press is an instrument used to crush raw garlic into smaller chunks, it is usually kept in a kitchen drawer.
#
# 52
# What is food grater?
# food grater is a device used to slice whole food into smaller parts, it is usually kept in a kitchen cupboard.
#
# 53
# What is kitchen scales?
# kitchen scales is a device to weigh and measure foods, sauces and powders for cooking, it is usually found in a kitchen cupboard.
#
# 54
# What is measuring spoon?
# measuring spoon is a spoon used to measure an amount of an ingredient, either liquid or dry, when cooking, it is usually located in a kitchen drawer.
#
# 55
# What is ovenproof dish?
# ovenproof dish is a dish made from a heat proof material such as glass, metal or earthenware that can withstand temperatures of 250 degrees, gas mark 9 and is suitable for use in the oven, it can usually be found in a kitchen cupboard.
#
# 56
# What is baking tray?
# baking tray is a a flat, rectangular metal pan used in an oven. It is often used for baking bread rolls, pastries and flat products such as cookies, sheet cakes, Swiss rolls and pizzas. It is usually kept in a kitchen drawer or cupboard
#
# 57
# What is stirring spoon?
# stirring spoon is a spoon used for stirring liquids and drinks such as cocktails, it is usually kept in a kitchen drawer.
#
# 58
# What is slotted spoon?
# slotted spoon is the term can be used to describe any spoon with slots, holes or other openings in the bowl of the spoon which let liquid pass through while preserving the larger solids on top, it is usually stored in a kitchen drawer.
#
# 59
# What is spatula?
# spatula is a broad, flat, flexible blade used to mix, spread and lift material including foods, drugs, plaster and paints. It is usually kept in a kitchen drawer or cupboard.
#
# 60
# What is oven glove?
# oven glove is also known as an oven mitt, is an insulated glove or mitten usually worn in the kitchen to easily protect the wearer's hand from hot objects such as ovens, stoves, cookware. They are usually located in the kitchen on a hook or in a drawer.
#
# 61
# What is pot holder?
# pot holder is a piece of textile or silicone used to cover the hand when holding hot kitchen cooking equipment, like pots and pans, and can usually be found in a kitchen cupboard.
#
# 62
# What is meat thermometer?
# meat thermometer is also known as a cooking thermometer is a thermometer used to measure the internal temperature of meat, especially roasts and steaks, and other cooked foods, it is usually kept in a kitchen drawer.
#
# 63
# What is pasta fork?
# pasta fork is a utensil used when preparing and serving various types of strand, ribbon or noodle pasta. The fork is spoon-shaped with upward pointing pieces, either dowel-like or prong-shaped, separated around or on the fork and lifter tool. It is usually kept in a kitchen drawer.
#
# 64
# What is corkscrew?
# corkscrew is a tool for drawing corks from wine bottles and other household bottles that may be sealed with corks. In its traditional form, a corkscrew simply consists of a pointed metallic helix attached to a handle, which the user screws into the cork and pulls to extract it. It is usually stored in a kitchen drawer.
#
# 65
# What is cling film?
# cling film is also known as, Plastic wrap, Saran wrap, cling wrap, Glad wrap or food wrap is a thin plastic film typically used for sealing food items in containers to keep them fresh over a longer period of time. It is usually stored in a kitchen cupboard.
#
# 66
# What is kitchen foil?
# kitchen foil is a sheet of aluminium prepared in thin metal leaves used to protect food when heating inside an oven, it is usually stored inside a kitchen drawer or cupboard.
#
# 67
# What is cutting board?
# cutting board is a durable board on which to place material for cutting. The kitchen cutting board is commonly used in preparing food  other types exist for cutting raw materials such as leather or plastic. Kitchen cutting boards are often made of wood or plastic and come in various widths and sizes and are usually found in a kitchen drawer or cupboard.
#
# 68
# What is salad spinner?
# salad spinner is also known as a salad tosser, is a kitchen tool used to wash and remove excess water from salad greens. It uses centrifugal force to separate the water from the leaves, enabling salad dressing to stick to the leaves without dilution. They are usually found in a kitchen cupboard.
#
# 69
# What is kitchen shears?
# kitchen shears is also known as kitchen scissors, are intended for cutting and trimming foods such as meats. They are usually stored in a kitchen drawer.
#
# 70
# What is lemon squeezer?
# lemon squeezer is a small kitchen utensil designed to extract juice from lemons or other citrus fruit such as oranges, grapefruit, or lime. It is designed to separate and crush the pulp of the fruit in a way that is easy to operate and usually stored in a kitchen drawer or cupboard.
#
# 71
# What is sharpening rod?
# sharpening rod is sometimes referred to as sharpening steel, whet steel, sharpening rod, butcher's steel, and chef's steel, is a rod of steel, ceramic or diamond-coated steel used to re-align blade edges. They are usually kept in a kitchen drawer or cupboard.
#
# 72
# What is knife sharpener?
# knife sharpener is a tool used to make a knife or similar tool sharp by grinding against a hard, rough surface, typically a stone, or a flexible surface with hard particles, such as sandpaper. Additionally, a leather razor strop, or strop, is often used to straighten and polish an edge. They are typically stored in a kitchen cupboard or drawer.
#
# 73
# What is skillet?
# skillet is a flat-bottomed metal pan used for frying, searing, and browning foods. They are usually stored in a kitchen cupboard.
#
# 74
# What is saute pans?
# saute pans is a hybrid between a saucepan and a frying pan. An extremely versatile addition to a kitchen, it can be used for a huge variety of dishes, they are usually stored in a kitchen cupboard.
#
# 75
# What is grill pan?
# grill pan is a pan that has raised edges with grill lines dispersed around 1 to 2 centimetres separated, they are usually stored in a kitchen cupboard.
#
# 76
# What is muffin pan?
# muffin pan is also know as a cupcake tray is a mould in which muffins or cupcakes are baked, they are usually stored in a kitchen drawer or cupboard.
#
# 77
# What is broiling pan?
# broiling pan is a pan used to broil foods in an oven such as steaks, roasts, or various cuts of meat, poultry, and vegetables. They are usually found in a kitchen cupboard or hung on a rack.
#
# 78
# What is stock pot?
# stock pot is a generic name for one of the most common types of cooking pot used worldwide. A stock pot is traditionally used to make stock or broth, which can be the basis for cooking more complex recipes. It is usually stored in a kitchen cupboard or rack.
#
# 79
# What is trivet?
# trivet is an object placed between a serving dish or bowl, and a dining table, usually to protect the table from heat damage. It is usually stored in a drawer in a kitchen or dining room.
#
# 80
# What is splatter guard?
# splatter guard is a device placed over a frying pan to prevent hot oil from spitting out of the pan, which often happens when pan frying at a high temperature. It is typically stored in a kitchen cupboard.
#
# 81
# What is kitchen scales?
# kitchen scales is a household tool that is used to measure the weight of dry, liquid, or chopped ingredients. It is usually stored in a kitchen cupboard.
#
# 82
# What is sponge?
# sponge is a cleaning aid made of soft, porous material. Typically used for cleaning impervious surfaces, sponges are especially good at absorbing water and water-based solutions. They are typically stored in a kitchen or cleaning cupboard.
#
# 83
# What is dish rack?
# dish rack is a device used to separate and dry dishes after cleaning, they are usually kept in the kitchen on a sideboard, sink or in a cupboard.
#
# 84
# What is ice cube tray?
# ice cube tray is a container designed to be filled with water, then placed in a freezer until the water freezes into ice, producing ice cubes. Ice trays are often flexible, so the frozen cubes can be easily removed by flexing the tray. When not in use, they are usually kept in a draw or cupboard in the kitchen.
#
# 85
# What is bin bag?
# bin bag is also known as a rubbish bag, garbage bag, bin liner, trash bag or refuse sack is a disposable bag used to contain solid waste. They are usually found in a kitchen or cleaning cupboard.
#
# 86
# What is serrated blade?
# serrated blade is a type of jagged blade used on saws and on some knives or scissors. It is also known as a dentated, sawtooth, or toothed blade. They are usually stored in the kitchen on a knife rack of inside a drawer.
#
# 87
# What is food turner?
# food turner is an elongated and thinner version of the common metal spatula, designed to easily slip under delicate fillets of fish. They are typically stored inside a kitchen drawer.
#
# 88
# What is zester?
# zester is a kitchen utensil for obtaining zest from lemons and other citrus fruit. They are typically found inside a kitchen drawer or cupboard.
#
# 89
# What is microwave?
# microwave is a oven (commonly referred to as a microwave) is an electric oven that heats and cook’s food by exposing it to electromagnetic radiation in the microwave frequency range. They are typically found in a kitchen on a sideboard.
#
# 90
# What is rice cooker?
# rice cooker is an automated kitchen appliance designed to boil or steam rice. They are usually found in a kitchen inside a cupboard or on a worktop.
#
# 91
# What is slow cooker?
# slow cooker is also known as a crock-pot, is a countertop electrical cooking appliance used to simmer at a lower temperature than other cooking methods, such as baking, boiling, and frying. They are usually found in a kitchen cupboard or on a sideboard.
#
# 92
# What is electric grill?
# electric grill is a grilling unit that uses an electric element to supply a constant heat source. They are typically installed inside a worktop or inside a kitchen cupboard.
#
# 93
# What is air fryer?
# air fryer is a small countertop convection oven designed to simulate deep frying without submerging the food in oil. They are typically found in a kitchen cupboard or on a worktop.
#
# 94
# What is bachelor grill?
# bachelor grill is also known as a mini oven or mini kitchen is a countertop kitchen appliance about the size of a microwave oven but instead can grill, bake, broil, or roast food. They are typically found inside a kitchen cupboard or on a countertop.
#
# 95
# What is barbecue?
# barbecue is a cooking method, a cooking device, a style of food, and a name for a meal or gathering at which this style of food is cooked and served. They are usually found in a kitchen cupboard, garage or garden shed.
#
# 96
# What is beehive oven?
# beehive oven is a dome-shaped beehive ovenbrick structure that looks a bit like an insect's nest, hence the name beehive. They are usually found in larger kitchens and gardens.
#
# 97
# What is brazier?
# brazier is a metal container used to burn charcoal or other solid fuel for cooking, heating, or cultural rituals. They are usually found in sheds and used in outdoor cooking spaces.
#
# 98
# What is bread machine?
# bread machine is also known as a bread maker is a home appliance for turning raw ingredients into baked bread. They are usually found in a kitchen inside a cupboard or on a worktop.
#
# 99
# What is burjiko?
# burjiko is a Somali-style cooker or charcoal burning stove, it is usually found in outdoor eating areas or in professional restaurants.
#
# 100
# What is butane torch?
# butane torch is a tool which creates an intensely hot flame using butane, a flammable gas. It is often used to flambe desserts and can usually be found in a kitchen draw or cupboard.
#
# 101
# What is chapati maker?
# chapati maker is a machine that flattens handmade dough balls into round roti’s and bakes them. They are typically found in a kitchen cupboard or on a worktop.
#
# 102
# What is cheese melter?
# cheese melter is a cooking device used to melt cheese, it is usually found in a kitchen cupboard or on a worktop.
#
# 103
# What is chocolatier?
# chocolatier is a type of high-necked metal pot shaped like a pitcher used for the traditional preparation of hot chocolate drinks. They are typically found in a kitchen cupboard or on a worktop.
#
# 104
# What is chorkor?
# chorkor is is an oven used for smoking fish, they are typically found in restaurants and outdoor eating areas.
#
# 105
# What is clome oven?
# clome oven is a type of masonry oven. It has a removable door made of clay or alternatively a cast-iron door. They are typically found in large kitchens and outdoor eating areas.
#
# 106
# What is comal?
# comal is a pan that is used for cooking a variety of items. It is made of cast iron and is very heavy. It is typically found in a kitchen cupboard or rack.
#
# 107
# What is combi oven?
# combi oven is a three-in-one oven which allows you to cook with steam, hot air (convection) or a combination of both, they are typically stand alone units in large kitchens.
#
# 108
# What is convection microwave?
# convection microwave is a stand alone oven that combines some of the features of two kitchen appliances, a microwave and a convection oven, allowing you to bake and roast foods in addition to heating them. They are typically located on a kitchen worktop.
#
# 109
# What is convection oven?
# convection oven is an oven that has fans to circulate air around food which gives a very even heat. The increased air circulation causes a fan-assisted oven to cook food faster than a conventional non-fan oven, which relies only on natural convection to circulate the hot air. They are typically stand alone units found in large kitchens.
#
# 110
# What is corn roaster?
# corn roaster is a large grill for cooking large batches of ears of corn at the same time, the are usually located in a kitchen cupboard or on a worktop.
#
# 111
# What is crepe maker?
# crepe maker is a cooking device used to make crepes, galettes, pancakes, blinis or tortillas. They are usually found in a kitchen cupboard or on a worktop.
#
# 112
# What is deep fryer?
# deep fryer is a kitchen appliance used for deep frying. Deep frying is a method of cooking by submerging food into oil at high heat. They are usually found in a kitchen cupboard or on a worktop.
#
# 113
# What is earth oven?
# earth oven is also known as a ground oven or cooking pit is one of the simplest and most ancient cooking structures. At its most basic, an earth oven is a pit in the ground used to trap heat and bake, smoke, or steam food. They are usually found in outdoor cooking areas.
#
# 114
# What is electric cooker?
# electric cooker is an electric powered cooking device for heating and cooking of food. An electric cooker often has four stoves and one or two ovens. They are usually built into kitchen worktops or if portable, located in a kitchen cupboard.
#
# 115
# What is espresso machine?
# espresso machine is a device that brews coffee by forcing pressurized water near boiling point through a puck of ground coffee and a filter in order to produce a thick, concentrated coffee called espresso. They are usually found in a kitchen cupboard or on a worktop.
#
# 116
# What is fire pot?
# fire pot is a container, usually earthenware, for carrying fire. Fire pots have been used since prehistoric times to transport fire from one place to another, for warmth while on the move, for cooking, in religious ceremonies and even as weapons of war.
#
# 117
# What is flat top grill?
# flat top grill is a cooking appliance that resembles a griddle but performs differently because the heating element is circular rather than straight. They are typically located in a kitchen cupboard or on a worktop.
#
# 118
# What is food steamer?
# food steamer is also known as a steam cooker, is a small kitchen appliance used to cook or prepare various foods with steam heat by means of holding the food in a closed vessel reducing steam escape. They are typically located in a kitchen cupboard or on a worktop.
#
# 119
# What is fufu machine?
# fufu machine is a kitchen appliance used to pound cooked starchy vegetables, particularly cassava, plantains, or yams, into the West and Central African staple food fufu. They are usually found in a kitchen cupboard or drawer.
#
# 120
# What is griddle?
# griddle is a cooking device consisting of a broad flat surface heated by gas, electricity, wood, or coal, with both residential and commercial applications. They are usually inbuilt into kitchen worktops or if portable stored in a kitchen cupboard.
#
# 121
# What is halogen oven?
# halogen oven is a halogen convection oven, or halogen cooking pot is a type of oven that utilizes a halogen lamp as its heating element. It is used primarily for cooking in large kitchen, they are typically built into kitchen worktops.
#
# 122
# What is haybox?
# haybox is also known as a straw box, fireless cooker, insulation cooker, wonder oven, self-cooking apparatus, Norwegian cooker or retained-heat cooker is a cooker that utilizes the heat of the food being cooked to complete the cooking process.
#
# 123
# What is horno?
# horno is a mud adobe-built outdoor oven used by Native Americans and early settlers of North America. Originally introduced to the Iberian Peninsula by the Moors, it was quickly adopted and carried to all Spanish-occupied lands.
#
# 124
# What is hot box?
# hot box is a device used to continue cooking food after the food has been partially cooked on a stove. This is done by insulating a container and placing the pot of food in the container to be sealed up.
#
# 125
# What is hot plate?
# hot plate is a portable self-contained tabletop small appliance cooktop that features one or more electric heating elements or gas burners.
#
# 126
# What is instant pot?
# instant pot is a Canadian brand of multi cookers. The multi cookers are electronically controlled, combined pressure cookers and slow cookers. The original cookers are marketed as 6-in-1 or more appliances designed to consolidate the cooking and preparing of food to one device.
#
# 127
# What is kamado?
# kamado is a traditional Japanese wood- or charcoal-fuelled cook stove, typically found in outdoor cooking areas and large kitchens.
#
# 128
# What is kitchner range?
# kitchner range is an oven with a cast-iron hotplate for over a fire with removable boiling rings. They are usually stand-alone units in large kitchens.
#
# 129
# What is kujiejun?
# kujiejun is a type of bamboo stove and is also a special term for tea stove. Popular during the Song Dynasty, the bamboo windscreen stove frame would fit on top of a brazier.
#
# 130
# What is kyoto box?
# kyoto box is a solar cooker constructed from polypropylene with an acrylic plastic cover. The oven traps the sun’s rays, creating enough heat to cook or boil water. They are typically stored in sheds and garages and used for outdoor cooking.
#
# 131
# What is makiyakinabe?
# makiyakinabe is a square or rectangular cooking pan used to make Japanese-style rolled omelettes. The pans are commonly made from metals such as copper and tin and can also be coated with a non-stick surface. They are typically found in a kitchen cupboard or on a pan rack.
#
# 132
# What is masonry oven?
# masonry oven is colloquially known as a brick oven or stone oven, it is an oven consisting of a baking chamber made of fireproof brick, concrete, stone, clay, or cob. They are typically located in outdoor cooking areas.
#
# 133
# What is multicooker?
# multicooker is an electric kitchen appliance for automated cooking using a timer. A typical multi cooker can boil, simmer, bake, fry, deep fry, grill roast, stew, steam and brown food. They are typically found in large kitchens.
#
# 134
# What is pancake machine?
# pancake machine is an electrically powered machine that automatically produces cooked pancakes. They are typically found in a kitchen cupboard or on a worktop.
#
# 135
# What is sandwich grill?
# sandwich grill is a kitchen countertop or stovetop grill that is used to make the traditional panini, a small Italian sandwich. Also referred to as a Panini Maker, Panini Press, or a Grill Press, the Panini Grill contains top and bottom ridged heat plates that press and grill the bread in one operation.
#
# 136
# What is popcorn maker?
# popcorn maker is a device used to pop popcorn. Since ancient times, popcorn has been a popular snack food, produced through the explosive expansion of kernels of heated corn. They are typically found in a kitchen cupboard or on a worktop.
#
# 137
# What is pressure cooker?
# pressure cooker is pressure cooking is the process of cooking food under high pressure steam, employing water or a water-based cooking liquid, in a sealed vessel known as a pressure cooker. They are typically found in a kitchen cupboard or on a worktop.
#
# 138
# What is pressure fryer?
# pressure fryer is a variation on pressure cooking where meat and cooking oil are brought to high temperatures while pressure is held high enough to cook the food more quickly. This leaves the meat very hot and juicy, they are typically found in a kitchen cupboard.
#
# 139
# What is reflector oven?
# reflector oven is a polished metal container, often made of tin. It is designed to enclose an article of food on all but one side, to cause it to bake by capturing radiant heat from an open fire, and reflecting the heat towards the food, avoiding smoke flavouring the food.
#
# 140
# What is remoska?
# remoska is a small portable electric oven with the cooking element housed in the lid of a pot. It consists of a Teflon-lined pan and a stand in addition to the lid mounted heating element. They are typically located in a kitchen cupboard or on a worktop.
#
# 141
# What is rice polisher?
# rice polisher is a machine for buffing kernels of rice to change their appearance, taste, and texture or for transforming brown rice into white rice. Rice polishers are abrasive machines that use talc or some other very fine dust to buff the outer surface of rice kernels. They are typically found in a kitchen cupboard or on a worktop.
#
# 142
# What is rotisserie?
# rotisserie is also known as spit-roasting, is a style of roasting where meat is skewered on a spit – a long solid rod used to hold food while it is being cooked over a fire in a fireplace or over a campfire or roasted in an oven. They are typically located on a kitchen worktop or installed as a stand alone unit.
#
# 143
# What is stove?
# stove is a device in which fuel is burned to heat either the space in which the stove is situated, or items placed on the heated stove or inside it in an oven.
#
# 144
# What is tandoor?
# tandoor is also known as tannour is a cylindrical clay or metal oven used in cooking and baking, they are typically found in large and professional kitchens.
#
# 145
# What is tangia?
# tangia is an urn-shaped terracotta cooking vessel. It is also the name of the stew cooked in the pot, they are typically found in a kitchen cupboard.
#
# 146
# What is toaster?
# toaster is an electric small appliance designed to expose various types of sliced bread to radiant heat, browning the bread so it becomes toast. They are typically located in a kitchen cupboard or on a worktop.
#
# 147
# What is turkey fryer?
# turkey fryer is an apparatus for deep-frying a turkey, they are typically found in large kitchens as stand alone units.
#
# 148
# What is vacuum fryer?
# vacuum fryer is a deep-frying device housed inside a vacuum chamber. Vacuum fryers are fit to process low-quality potatoes that contain higher sugar levels than normal, as they frequently must be processed in spring and early summer before the potatoes from the new harvest become available. They are usually found in large and professional kitchens as standalone units.
#
# 149
# What is waffle iron?
# waffle iron is also known as a waffle maker is a utensil or appliance used to cook waffles. It comprises two metal plates with a connecting hinge, moulded to create the honeycomb pattern found on waffles. They are typically found in the kitchen cupboard or on a worktop.
#
# 150
# What is wet grinder?
# wet grinder is a tool for abrasive cutting of hard materials, or a food preparation appliance used especially in Indian cuisine for grinding food grains to produce a paste or batter. They are typically found in a kitchen cupboard or drawer.
#
# 151
# What is food boiler?
# food boiler is a machine that generates steam or hot water to process, cook, or sanitize food products including meat, fruits, and vegetables, they are typically found in a kitchen cupboard or on a worktop.
#
# 152
# What is coffee percolator?
# coffee percolator is a type of pot used for the brewing of coffee by continually cycling the boiling or nearly boiling brew through the grounds using gravity until the required strength is reached, they are typically located in a kitchen cupboard or on a worktop.
#
# 153
# What is apple corer?
# apple corer is a device for removing the core and pips from an apple. It may also be used for similar fruits, such as pears or quince. They are typically found in a kitchen drawer or cupboard.
#
# 154
# What is apple slicer?
# apple slicer is a device designed to both core and slices apples. They are typically located in a kitchen drawer or cupboard.
#
# 155
# What is baster?
# baster is sometimes called a turkey baster, is a tube attached to a rubber bulb used to suck up and squirt cooking liquid from a pan onto roasting meat or poultry, thus moistening it. They are typically found in a kitchen drawer or cupboard.
#
# 156
# What is beanpot?
# beanpot is a deep, wide-bellied, short-necked vessel used to cook bean-based dishes. Beanpots are typically made of ceramic, though some are made of other materials, such as cast iron. They are usually found in a kitchen cupboard or drawer.
#
# 157
# What is cookie press?
# cookie press is a device for making pressed cookies such as spritzgebäck. It consists of a cylinder with a plunger on one end, which is used to extrude cookie dough through a small hole at the other end. They are usually located in a kitchen cupboard.
#
# 158
# What is browning dish?
# browning dish is a device used to simulate a frying pan or skillet so that foods such as steaks, chops, hamburgers, and even French toast can be prepared. They are usually located in a kitchen cupboard or on a pan rack.
#
# 159
# What is pie server?
# pie server is also called a cake shovel, pie knife, crepe spade, pie-getter, pie lifter, pie spatula, cake knife, or cake slice, is a serving utensil used in the cutting and serving of pies and cakes. They are usually located in a kitchen cupboard.
#
# 160
# What is cheese cutter?
# cheese cutter is an implement for cutting cheese, especially by means of a wire which can be pulled through the cheese. They are usually found in a kitchen drawer in the cupboard.
#
# 161
# What is cheese knife?
# cheese knife is a knife with a concaved blade made to cut hard cheeses, they are usually found in a kitchen drawer or on a knife rack.
#
# 162
# What is cheesecloth?
# cheesecloth is a loose-woven gauze-like carded cotton cloth used primarily in cheese making and cooking. They are usually located in a kitchen cupboard or drawer.
#
# 163
# What is cherry pitter?
# cherry pitter is a device for removing the pit from a cherry, leaving the cherry relatively intact. They are usually stored in a kitchen drawer.
#
# 164
# What is chinois?
# chinois is a conical sieve with an extremely fine mesh. It is used to strain custards, purees, soups, and sauces, producing a very smooth texture. They are usually located in a kitchen cupboard.
#
# 165
# What is clay pot?
# clay pot is a pot made of unglazed or glazed pottery, they are usually stored in a kitchen cupboard or on a rack.
#
# 166
# What is cookie cutter?
# cookie cutter is a tool that is used for cutting cookies into a particular shape before you bake them. They are usually stored in a kitchen drawer or cupboard.
#
# 167
# What is crab cracker?
# crab cracker is a device used to crack the tough shells of crabs, lobsters, and any other edible crustaceans, they are usually located in a kitchen drawer.
#
# 168
# What is scraper?
# scraper is a kitchen implement made of metal, plastics, wood, rubber or silicone rubber. They are usually located in a kitchen drawer or cupboard.
#
# 169
# What is egg piercer?
# egg piercer is a device that pierces the air pocket of an eggshell with a small needle to keep the shell from cracking during hard-boiling. If both ends of the shell are pierced, the egg can be blown out while preserving the shell. They are typically stored in a kitchen cupboard or drawer.
#
# 170
# What is egg poacher?
# egg poacher is a device that is used to poach eggs, a poached egg is an egg that has been cooked, outside the shell, by poaching, as opposed to simmering or boiling. They are usually stored in a kitchen cupboard or drawer.
#
# 171
# What is egg separator?
# egg separator is a utensil used to separate the egg white from the egg yolk, they are usually stored in a kitchen drawer or cupboard.
#
# 172
# What is egg slicer?
# egg slicer is a utensil used to slice peeled, hard-boiled eggs quickly and evenly. They are usually stored in a kitchen drawer or cupboard.
#
# 173
# What is egg timer?
# egg timer is a device for timing the cooking of a boiled egg, traditionally a sealed glass container with a narrow neck in the middle through which, when the flask is inverted, sand flows for a fixed amount of time. They are typically stored in a kitchen drawer, cupboard or on a worktop.
#
# 174
# What is fat separator?
# fat separator is a device that resembles measuring cups and are designed to drain liquid while keeping the fat layer contained. They are typically stored in a kitchen cupboard.
#
# 175
# What is flour sifter?
# flour sifter is a tool that breaks up any lumps in the flour and aerates it at the same time by pushing it through a gadget that is essentially a cup with a fine strainer at one end. They are typically stored in a kitchen cupboard.
#
# 176
# What is food mill?
# food mill is a food preparation utensil for mashing and sieving soft foods, they are typically stored in a kitchen cupboard.
#
# 177
# What is funnel?
# funnel is a cooking tool with a large open top that slopes down and decreases in size forming a small diameter outlet allowing placement into smaller areas. They are typically stored in a kitchen cupboard or cabinet.
#
# 178
# What is grapefruit knife?
# grapefruit knife is a special type of knife designed specifically for cutting grapefruit. Grapefruit knives are small with a curved serrated blade, designed to hug the curves of the grapefruit. They are usually stored in a kitchen drawer.
#
# 179
# What is gravy strainer?
# gravy strainer is also known as a gravy skimmer, fat separator, fat strainer is a device used to separate fats and juices from gravy’s, stocks and sauces. They are typically stored in a kitchen cupboard or cabinet.
#
# 180
# What is herb chopper?
# herb chopper is a cooking tool specifically designed for chopping fresh herbs. There are a variety of different designs and styles for herb choppers. They are usually stored in a kitchen drawer.
#
# 181
# What is honey dipper?
# honey dipper is a kitchen utensil used to collect viscous liquid (generally honey) from a container, which it then exudes to another location. They are usually stored in a kitchen drawer.
#
# 182
# What is lame?
# lame is a double-sided blade that is used to slash the tops of bread loaves in artisan baking. A lame is used to score bread just before the bread is placed in the oven. They are usually stored in a kitchen drawer or on a knife rack.
#
# 183
# What is citrus reamer?
# citrus reamer is also known as a lemon reamer or simply a reamer, is a small kitchen utensil used to extract the juice from a lemon or other small citrus fruit. They are usually stored in a kitchen drawer or cupboard.
#
# 184
# What is lemon squeezer?
# lemon squeezer is a small kitchen utensil designed to extract juice from lemons or other citrus fruit such as oranges, grapefruit, or lime. It is designed to separate and crush the pulp of the fruit in a way that is easy to operate. They are usually stored in a kitchen drawer or cupboard.
#
# 185
# What is lobster pick?
# lobster pick is also known as a lobster fork is a long, narrow food utensil used to extract meat from joints, legs, claws, and other small parts of a lobster. Lobster picks are usually made of stainless steel and weigh as much as an average teaspoon, they are usually stored in a kitchen drawer.
#
# 186
# What is mandoline?
# mandoline is a culinary utensil used for slicing and for cutting juliennes  with suitable attachments, it can make crinkle-cuts. Its name is derived from the wrist-motion of a skilled user of a mandoline, which resembles that of a player of the musical instrument mandolin. They are usually stored in a kitchen cupboard or cabinet.
#
# 187
# What is colander?
# colander is a kitchen utensil used to strain foods such as pasta or to rinse vegetables, they are usually stored in a kitchen cupboard or cabinet.
#
# 188
# What is meat grinder?
# meat grinder is a kitchen appliance for fine chopping and/or mixing of raw or cooked meat, fish, vegetables or similar food. They are typically stored in a kitchen cupboard or on a worktop.
#
# 189
# What is melon baller?
# melon baller is a small spoon-like tool used to cut round- or oval-shaped sections of melon, known as melon balls, by pressing them into the melon's flesh and rotating. They are typically stored in a kitchen drawer or cabinet.
#
# 190
# What is mezzaluna?
# mezzaluna is a knife consisting of one or more curved blades with a handle on each end, which is rocked back and forth chopping the ingredients below with each movement. They are typically stored in a kitchen drawer or knife rack.
#
# 191
# What is milk frother?
# milk frother is a milk frother is a utensil for making milk froth, typically to be added to coffee. They are typically stored in a kitchen drawer.
#
# 192
# What is mortar and pestle?
# mortar and pestle is implements used since ancient times to prepare ingredients or substances by crushing and grinding them into a fine paste or powder. They are typically stored in a kitchen cupboard or cabinet.
#
# 193
# What is nutmeg grater?
# nutmeg grater is also known as a nutmeg rasp, is a device used to grate a nutmeg seed. They are typically stored in a kitchen drawer.
#
# 194
# What is pastry bag?
# pastry bag is a triangular-shaped bag made from cloth, paper, plastic, or the intestinal lining of a lamb, that is squeezed by hand to pipe semi-solid foods by pressing them through a hole. They are typically stored in a kitchen drawer or cupboard.
#
# 195
# What is pastry blender?
# pastry blender is a cooking utensil used to mix a hard fat into flour to make pastries. They are typically stored in a kitchen cupboard or cabinet.
#
# 196
# What is pepper mill?
# pepper mill is a device, of which you turn by hand to crush the peppercorns inside, they are typically stored in a kitchen cupboard, cabinet or left on a table.
#
# 197
# What is pie bird?
# pie bird is also known as a pie vent, pie whistle, pie funnel, or pie chimney is a hollow ceramic device, originating in Europe, shaped like a funnel, chimney, or outstretched bird with open beak used for supporting or venting a pie. They are usually stored in a kitchen cupboard or cabinet.
#
# 198
# What is roller docker?
# roller docker is also known as a dough docker, roto-fork, or simply docker is a food preparation utensil which resembles either a small, spiked rolling pin, or a small rotary tiller. They are typically stored in a kitchen drawer or cupboard.
#
# 199
# What is salt shaker?
# salt shaker is also called a salt cellar in British English, are condiment dispensers used in Western culture that are designed to allow diners to distribute grains of edible salt. They are typically stored in a kitchen cupboard or on a table top.
#
# 200
# What is tomato knife?
# tomato knife is a small serrated kitchen knife designed to slice through tomatoes. The serrated edge allows the knife to penetrate the tomatoes’ skin quickly and with a minimum of pressure without crushing the flesh. They are typically stored in a kitchen drawer or on a knife rack.
#
# 201
# What is freezer?
# freezer is a refrigerated cabinet or room for preserving food at very low temperatures. They are usually standalone units in kitchens.
#
# 202
# What is skewer?
# skewer is a thin metal or wood stick used to hold pieces of food together, they are usually stored in a kitchen drawer or cupboard.

# %% [markdown]
# **Checking GPT-2 124M capabilities of showing common-sense**

# %% [markdown]
# **Alternative Products**

# %%
# question 1 - plain flour
question = "What can be used instead of plain flour?"
answer = "oat flour, bread flour, cake flour or coconut flour."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of plain flour?
# Answer: oat flour, bread flour, cake flour or coconut flour.
# Answer generated by GPT-2
# What can be used instead of plain flour?
#
# Because of its high starch content, the flour can be mixed easily with others to make a low-carb, low-sugar, low-sugar meal.
#
# How to make a low-carb meal with your favorite flour

# %%
# question 2 - olive oil
question = "What can be used instead of olive oil?"
answer = "peanut oil, butter, coconut milk, ghee, walnut oil, sunflower oil, canola oil or vegetable oil"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of olive oil?
# Answer: peanut oil, butter, coconut milk, ghee, walnut oil, sunflower oil, canola oil or vegetable oil
# Answer generated by GPT-2
# What can be used instead of olive oil?
#
# If you're already using olive oil, stick to the regular recipe.
#
# I personally have a more complex recipe for a red wine that is very drought resistant, but that can also be used as a natural supplement.
#
# I haven

# %%
# question 3 - salt
question = "What can be used instead of salt?"
answer = "mint, rosemary, nutmeg, basil, cardamon, chili, cinnamon or chives"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of salt?
# Answer: mint, rosemary, nutmeg, basil, cardamon, chili, cinnamon or chives
# Answer generated by GPT-2
# What can be used instead of salt? Significantly less than 2% of C. difficile is salt. Its analytical activity is about right for sodium chloride salt. As sodium chloride salts are highly soluble in water, they have an antimicrobial profile, and are highly antioxidant and anti-

# %%
# question 4 - black pepper
question = "What can be used instead of black pepper?"
answer = "white pepper, cayenne pepper or papaya seeds"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of black pepper?
# Answer: white pepper, cayenne pepper or papaya seeds
# Answer generated by GPT-2
# What can be used instead of black pepper?
#
# Some people have suggested that black pepper is not a proper food option for the root vegetable, and that it should be avoided altogether without concern. This is a false assumption. Black pepper is not a-type of vegetable that is used in all

# %%
# question 5 - eggs
question = "What can be used instead of eggs?"
answer = "commercial egg substitute or tofu."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of eggs?
# Answer: commercial egg substitute or tofu.
# Answer generated by GPT-2
# What can be used instead of eggs?
#
# There are several methods of making eggs. Egg making involves stirring water into the egg, or mixing it with salt and baking soda. This can be done in the oven or in a mixing bowl. If you are using a bakeshaker

# %%
# question 6 - milk
question = "What can be used instead of milk?"
answer = "cream, powerdered milk, plain yogurt, nut milk, soy milk, oat milk or rice milk"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of milk?
# Answer: cream, powerdered milk, plain yogurt, nut milk, soy milk, oat milk or rice milk
# Answer generated by GPT-2
# What can be used instead of milk?
#
# My friend and I have been trying to enjoy the milk for a few years now, and the taste of it is great. Not too subtle, just not too sweet. It's the best kind of milk on the market that's been around

# %%
# question 7 - sausage
question = "What can be used instead of sausage?"
answer = "vegetarian sausages"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of sausage?
# Answer: vegetarian sausages
# Answer generated by GPT-2
# What can be used instead of sausage?
#
# I have a huge list of ingredients to use to make sausage. The only thing I'm not very familiar with is flour. I use a very small amount of it just because I need it but it's very easy. It's mostly made

# %%
# question 8 - mustard
question = "What can be used instead of mustard?"
answer = "turmeric, wasabi powder or horseradish powder"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of mustard?
# Answer: turmeric, wasabi powder or horseradish powder
# Answer generated by GPT-2
# What can be used instead of mustard?
#
# You can use mustard to replace sour cream or regular mustard. It goes great with yogurt or other dishes.
#
# You can also use mustard to replace some things called "slugs". These are the things you can use to keep the mix

# %%
# question 9 - beef stock
question = "What can be used instead of beef stock?"
answer = "vegetable stock, chicken stock, bouillion stock or red wine"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of beef stock?
# Answer: vegetable stock, chicken stock, bouillion stock or red wine
# Answer generated by GPT-2
# What can be used instead of beef stock?
#
# The simplest, most economical way to generate meat is to use low-fat gravy. For most of us, gravy is probably our favorite. There are recipes out there, but if you're a meat lover, I highly recommend you try it

# %%
# question 10 - cabbage
question = "What can be used instead of cabbage?"
answer = "brussels sprouts, yu choy, kangkong or bok choy"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of cabbage?
# Answer: brussels sprouts, yu choy, kangkong or bok choy
# Answer generated by GPT-2
# What can be used instead of cabbage? You can use applesauce or applesauce vinegar.
#
# The good news is, there are a lot of different ways to use cabbage to replace your regular, organic food.
#
# Here are some good tips for using cabbage:<|endoftext|>You

# %%
# question 11 - garlic
question = "What can be used instead of garlic?"
answer = "garlic oil, onion, chives or lemon zest"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of garlic?
# Answer: garlic oil, onion, chives or lemon zest
# Answer generated by GPT-2
# What can be used instead of garlic? I think you can use pasta-like things, but even those are not really suitable.
#
# I'm not sure what I would say about this blend. I really feel bad for anyone who is gluten intolerant. Let's take the simple thing

# %%
# question 12 - mixed herbs
question = "What can be used instead of mixed herbs?"
answer = "basil, marjoram, min, oregano or parsley"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of mixed herbs?
# Answer: basil, marjoram, min, oregano or parsley
# Answer generated by GPT-2
# What can be used instead of mixed herbs?
#
# Try using mixed herbs to prepare homemade herbs. Stir herbs, water or water flaked into the seeds. Then use dry herbs to make a soft drink.
#
# Tastes like cinnamon and ginger.
#
# One-tenth of

# %%
# question 13 - butter
question = "What can be used instead of butter?"
answer = "olive oil, ghee, greek yogurt, avocado, pumpkin puree or coconut oil"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of butter?
# Answer: olive oil, ghee, greek yogurt, avocado, pumpkin puree or coconut oil
# Answer generated by GPT-2
# What can be used instead of butter?
#
# [[In the bathroom, I grab a bag and remove a little baggie of butter from the fridge in the fridge and let it sit. The freezer bag is cold and has to be put in the freezer.]] [[Grab the bag from

# %%
# question 14 - potato
question = "What can be used instead of potato?"
answer = "cauliflower or cabbage"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of potato?
# Answer: cauliflower or cabbage
# Answer generated by GPT-2
# What can be used instead of potato?
#
# A tomato is a potato that is cooked in a large pot. In this case, the pot is called a potato brine pot. The brine pot is heated to a high temperature and the potato is peeled and marinated. The potato

# %%
# question 15 - frozen peas
question = "What can be used instead of frozen peas?"
answer = "lima beans, green pepper, green onion or broad beans"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of frozen peas?
# Answer: lima beans, green pepper, green onion or broad beans
# Answer generated by GPT-2
# What can be used instead of frozen peas? If you're thinking about using frozen peas, here are some ideas.
#
# Don't dry peas! It's not a snap.
#
# If you're not using frozen peas, you should be using some kind of food processor. You can buy

# %%
# question 16 - mushrooms
question = "What can be used instead of mushrooms?"
answer = "zucchini, eggplant, chickpeas, tofu, onions or cilantro"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of mushrooms?
# Answer: zucchini, eggplant, chickpeas, tofu, onions or cilantro
# Answer generated by GPT-2
# What can be used instead of mushrooms?
#
# You can use mushrooms instead of green onions.
#
# You can use mushrooms instead of peanut butter.
#
# You can't use peas instead of kale.
#
# You can't use mushrooms instead of red peppers.
#
# You can't

# %%
# question 17 - oat meal
question = "What can be used instead of oat meal?"
answer = "amaranth, teff, buckwheat, wheat berries, spelt or quinoa"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of oat meal?
# Answer: amaranth, teff, buckwheat, wheat berries, spelt or quinoa
# Answer generated by GPT-2
# What can be used instead of oat meal? Try some of the following:
#
# Traditional Chinese Tea: Have you ever tried a traditional Chinese tea and felt like it was too bland? Yes, you can try it! You can add a spoonful of tea to the bowl to give a nice

# %%
# question 18 - yeast
question = "What can be used instead of yeast?"
answer = "baking powder. baking soda or sourdough"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of yeast?
# Answer: baking powder. baking soda or sourdough
# Answer generated by GPT-2
# What can be used instead of yeast?
#
# 1. Baking flour directly into dough.
#
# 2. If you have a baking sheet, make a pre-heated oven and bake on a rack at 350 degrees Celsius.
#
# 3. If using a plastic baking sheet,

# %%
# question 19 - bacon
question = "What can be used instead of bacon?"
answer = "pork, chicken or turkey bacon"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of bacon?
# Answer: pork, chicken or turkey bacon
# Answer generated by GPT-2
# What can be used instead of bacon?
#
# I like bacon because I've always enjoyed the savory flavors of the bacon.
#
# I've always loved the salty, sour, slightly sweet, sticky taste of bacon.
#
# I've always been a bacon fan and I thought bacon

# %%
# question 20 - tomatoes
question = "What can be used instead of tomatoes?"
answer = "olives, red peppers or red capsicum"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of tomatoes?
# Answer: olives, red peppers or red capsicum
# Answer generated by GPT-2
# What can be used instead of tomatoes?
#
# In my opinion, the opposite is true: The product of the 2-year process, which means that the seed is not ready to be used until the end of the next year, and therefore, only the seeds used in this process will

# %%
# question 21 - baked beans
question = "What can be used instead of baked beans?"
answer = "peas or chickpeas"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of baked beans?
# Answer: peas or chickpeas
# Answer generated by GPT-2
# What can be used instead of baked beans? There's a recipe you can make for using the 4-ounce batch of beans that you used for your baby's birthday party.
#
# You can use this recipe as a morning snack for your baby. Keep in mind that you may need to add

# %%
# question 22 - paprika
question = "What can be used instead of paprika?"
answer = "catenne pepper, chili powder or chili flakes"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of paprika?
# Answer: catenne pepper, chili powder or chili flakes
# Answer generated by GPT-2
# What can be used instead of paprika?
#
# There are two ways to apply paprika to root. One is to apply on a pea-sized piece of root, like a bundle of peppermint leaves. The other is to apply a clove of paprika on a piece of

# %%
# question 23 - feta
question = "What can be used instead of feta?"
answer = "ricotta, halloumi, goats cheese or queso fresc"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of feta?
# Answer: ricotta, halloumi, goats cheese or queso fresc
# Answer generated by GPT-2
# What can be used instead of feta?
#
# Metabolic mediators such as insulin insulin is the main killer of metabolic syndrome, which in turn causes a lot of damage. As a result of this, the most important thing is to consume healthy fats and low-calorie foods, especially

# %%
# question 24 - parsley
question = "What can be used instead of parsley?"
answer = "chervil, tarragon, chives, oregano, arugula, endive, cilantro or basil"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of parsley?
# Answer: chervil, tarragon, chives, oregano, arugula, endive, cilantro or basil
# Answer generated by GPT-2
# What can be used instead of parsley?
#
# I had a chef ask me why I have parsley, and I figured I'd share some of the food I've eaten with you. It's a simple recipe, but it's incredibly delicious.
#
# It's good for you.

# %%
# question 25 - cheddar
question = "What can be used instead of cheddar?"
answer = "cantal, edam, mimolette, gouda, emmental or french gruyere"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of cheddar?
# Answer: cantal, edam, mimolette, gouda, emmental or french gruyere
# Answer generated by GPT-2
# What can be used instead of cheddar?
#
# What's the difference between a bacon cheeseburger and a ham sandwich?
#
# You can use a ham sandwich instead of a bacon cheeseburger but you can't butcher it. It's still ham.
#
# What about a ham

# %%
# question 26 - pork fillet
question = "What can be used instead of pork fillet?"
answer = "pork sirloin, pork tenderloin, chicken, turkey or beef"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of pork fillet?
# Answer: pork sirloin, pork tenderloin, chicken, turkey or beef
# Answer generated by GPT-2
# What can be used instead of pork fillet? Simply use the bevy of substitutes that are available, such as fresh pineapple, fresh mayonnaise, fresh shredded garlic, and fresh skinless shrimp. We also have a variety of other recipes for homemade French fries.
#
# You can also order

# %%
# question 27 - red peppers
question = "What can be used instead of red peppers?"
answer = "poblano peppers, cubanelle, anaheim peppers, pepperoncini, jalapeno, pimiento, zucchini or broccoli"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of red peppers?
# Answer: poblano peppers, cubanelle, anaheim peppers, pepperoncini, jalapeno, pimiento, zucchini or broccoli
# Answer generated by GPT-2
# What can be used instead of red peppers?
#
# Red peppers can be used as a flavoring for certain types of chili. Unfortunately, they are made from sugar and are not much more nutritious than other types of peppers.
#
# Red peppers are a great substitute for dextrose, a

# %%
# question 28 - courgette
question = "What can be used instead of courgette?"
answer = "cucumber or zucchini"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of courgette?
# Answer: cucumber or zucchini
# Answer generated by GPT-2
# What can be used instead of courgette?
#
# In another world, one can think of in the past, together with things that had happened, as possible and without any reason. He who does not know this, can never think of his future.
#
# In another world, one can

# %%
# question 29 - chickpeas
question = "What can be used instead of chickpea?"
answer = "green peas, cannellini beans, black beans, lentils, soybeans, mung beans, peanuts or hazelnuts"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of chickpea?
# Answer: green peas, cannellini beans, black beans, lentils, soybeans, mung beans, peanuts or hazelnuts
# Answer generated by GPT-2
# What can be used instead of chickpea?
#
# 1. Taste the chickpea.
#
# 2. Look at the chickpea.
#
# 3. Look at the chickpea.
#
# 4. Taste the chickpea.
#
# 5. Look at the chick

# %%
# question 30 - chicken stock
question = "What can be used instead of chicken stock?"
answer = "beef stock or vegatable stock"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What can be used instead of chicken stock?
# Answer: beef stock or vegatable stock
# Answer generated by GPT-2
# What can be used instead of chicken stock? You can use either vegetable stock or vegetable oil, but I am not sure if you can use both. Vegetable oil is a blend of both. A blend of fish oil and vegetable oil. It is not a substitute for chicken stock, but it

# %% [markdown]
# **Utensils Description**

# %%
# question 1 - bowl
question = "What is a bowl?"
answer = "a cooking container that is usually larger than a cup and kept in a cupboard in the kitchen, it is typically made from glass, ceramic, plastic."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a bowl?
# Answer: a cooking container that is usually larger than a cup and kept in a cupboard in the kitchen, it is typically made from glass, ceramic, plastic.
# Answer generated by GPT-2
# What is a bowl? (Also, it's a two-piece, not a two-piece.)
#
# A bowl consists of a bowl shaped like a rim, with a few pieces of the same shape [such as a round hole or a rim] in between,

# %%
# question 2 - spoon
question = "What is a spoon?"
answer = "an eating or cooking utensil consisting of a small shallow bowl with a relatively long handle made from metal, plastic, wood it is usually kept in the kitchen, in drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a spoon?
# Answer: an eating or cooking utensil consisting of a small shallow bowl with a relatively long handle made from metal, plastic, wood it is usually kept in the kitchen, in drawer.
# Answer generated by GPT-2
# What is a spoon?
#
# When you remove the spoon from the block, you will see that it has been fully removed. This is because the block is attached to a piece of metal. Properly placed it will protect against corrosion.
#
# The spoon has been removed

# %%
# question 3 - sieve
question = "What is a sieve?"
answer = "a metal or plastic device with meshes or perforations through which finer particles of a mixture are sifted, it is usually kept in a kitchen and stored in a cupboard. : "

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a sieve?
# Answer: a metal or plastic device with meshes or perforations through which finer particles of a mixture are sifted, it is usually kept in a kitchen and stored in a cupboard. :
# Answer generated by GPT-2
# What is a sieve?
#
# A sieve is a device to remove a liquid from a container or other product. It is used to moisten a container and to prevent it from becoming gaseous.
#
# What is a sieve?
#
# A sieve

# %%
# question 4 - pan
question = "What is a pan?"
answer = "a shallow and open cooking container made from metal, it is usually found in a kitchen and stored in a cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a pan?
# Answer: a shallow and open cooking container made from metal, it is usually found in a kitchen and stored in a cupboard.
# Answer generated by GPT-2
# What is a pan? A pan is a device that allows you to place your food directly on the surface of the pan. Panes are often used to remove starchy foods and beverages from your food. They are also used to make a variety of other foods like soups

# %%
# question 5 - baking tray
question = "What is a baking tray?"
answer = "a metal rectangular sheet with a rolled edge used for baking, it is usually found in a kitchen inside a cupboard or draw."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a baking tray?
# Answer: a metal rectangular sheet with a rolled edge used for baking, it is usually found in a kitchen inside a cupboard or draw.
# Answer generated by GPT-2
# What is a baking tray?
#
# A baking tray is a small box that can be inserted into ovens. It is used for metal baking pans and oil pans. It is usually placed on a large surface and held in one hand, while the other hand is held in the

# %%
# question 6 - whisk
question = "What is a whisk?"
answer = "a metal or plastic wire utensil used for beating food by hand and is usually found in a kitchen inside a drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a whisk?
# Answer: a metal or plastic wire utensil used for beating food by hand and is usually found in a kitchen inside a drawer.
# Answer generated by GPT-2
# What is a whisk?
#
# A whisk is a whisk that's made from one or more ingredients, and not from a single ingredient. A whisk is a whisk that is made of only one or more ingredients, but is made of fewer and fewer ingredients. The whisk can

# %%
# question 7 - oven
question = "What is a oven?"
answer = "a cooking chamber used for baking, heating, or drying and is usually found in a kitchen. "

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a oven?
# Answer: a cooking chamber used for baking, heating, or drying and is usually found in a kitchen.
# Answer generated by GPT-2
# What is a oven?
#
# A oven is a type of oven designed to produce a certain amount of heat while maintaining a comfortable temperature. When you put the oven into a heated room, a certain amount of heat is created.
#
# A oven is opened to heat the

# %%
# question 8 - cellophane
question = "What is a cellophane?"
answer = "thin transparent plastic sheets used to package or cover food items, it is usually kept in a kitchen inside a drawer or cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a cellophane?
# Answer: thin transparent plastic sheets used to package or cover food items, it is usually kept in a kitchen inside a drawer or cupboard.
# Answer generated by GPT-2
# What is a cellophane?
#
# A cellophane is a substance that is produced from the outer membrane of a cell. It is composed of two parts: the outer membrane and a condensed membrane, which is formed from the very end of the membrane, and is composed of

# %%
# question 9 - tea towel
question = "What is a tea towel?"
answer = "a fabric cloth used for drying dishes, it is typically found in a kitchen or airing cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a tea towel?
# Answer: a fabric cloth used for drying dishes, it is typically found in a kitchen or airing cupboard.
# Answer generated by GPT-2
# What is a tea towel?
#
# A tea towel is a temporary device used to keep the water from soaking. The water is then collected by a drain or on a drain break. The tea towel should not be used during deep water runs. When used for long periods of time

# %%
# question 10 - frying pan
question = "What is a frying pan?"
answer = "an open metal container with a handle that is used for frying foods, it is usually found in a kitchen inside a cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a frying pan?
# Answer: an open metal container with a handle that is used for frying foods, it is usually found in a kitchen inside a cupboard.
# Answer generated by GPT-2
# What is a frying pan?
#
# A frying pan is a pan where you can measure the amount of oil your food is being made with. It's a very useful tool when you're cooking food, and it can save you the trouble of finding the correct amount of oil.

# %%
# question 11 - kettle
question = "What is a kettle?"
answer = "a metal or plastic vessel used for boiling liquids, it is usually found in a kitchen on a tabletop or inside a cupboard"

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a kettle?
# Answer: a metal or plastic vessel used for boiling liquids, it is usually found in a kitchen on a tabletop or inside a cupboard
# Answer generated by GPT-2
# What is a kettle? A kettle is an almanac, a membership card, a notebook, a calendar, or a ledger. The only thing that is ever seen as a kettle is a map, or a printed card. What a kettle is always used for is to keep

# %%
# question 12 - kitchen knife
question = "What is a kitchen knife?"
answer = "a cutting instrument consisting of a sharp blade fastened to a handle, it is usually found in a kitchen inside a draw."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a kitchen knife?
# Answer: a cutting instrument consisting of a sharp blade fastened to a handle, it is usually found in a kitchen inside a draw.
# Answer generated by GPT-2
# What is a kitchen knife?
#
# A kitchen knife is a sharpened knife running under the blade of the knife. It is designed to be used in conjunction with a knife blade.
#
# For more information about kitchen knives, please see the table above.
#
# Why is

# %%
# question 13 - saucepan
question = "What is a saucepan?"
answer = "a small deep metal cooking pan with a handle and is usually kept in a kitchen cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a saucepan?
# Answer: a small deep metal cooking pan with a handle and is usually kept in a kitchen cupboard.
# Answer generated by GPT-2
# What is a saucepan?
#
# A saucepan is a hot, warm vessel that can be used to keep hot liquid in the refrigerator. It's a thin, clean, and well-organized vessel that can be used to cool down and freeze foods or other liquids.

# %%
# question 14 - greaseproof paper
question = "What is a greaseproof paper?"
answer = "a heavy stiff waxed paper used in cooking and baking to prevent food from sticking to cooking trays and is usually kept inside a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a greaseproof paper?
# Answer: a heavy stiff waxed paper used in cooking and baking to prevent food from sticking to cooking trays and is usually kept inside a kitchen drawer.
# Answer generated by GPT-2
# What is a greaseproof paper?
#
# You may be wondering when it comes to making the paper. A greaseproof paper is a type of paper that is coated with carbon dioxide that is used to paint and then spread over a surface. It may look like a paper

# %%
# question 15 - cup
question = "What is a cup?"
answer = "a ceramic, porcelain or glass bowl-shaped drinking vessel usually kept in a kitchen cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a cup?
# Answer: a ceramic, porcelain or glass bowl-shaped drinking vessel usually kept in a kitchen cupboard.
# Answer generated by GPT-2
# What is a cup? A cup is a small, flat piece of paper that is held on a table or shelf with the words "Welcome to The World of Content."
#
# Cup and cuplets are known as "apartheid slips" because they often seem to

# %%
# question 16 - measuring jug
question = "What is a measuring jug?"
answer = "a plastic or glass cup that has markings for measuring liquids when cooking, it is usually kept inside a kitchen cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a measuring jug?
# Answer: a plastic or glass cup that has markings for measuring liquids when cooking, it is usually kept inside a kitchen cupboard.
# Answer generated by GPT-2
# What is a measuring jug? A measuring jug is a tool that you use to measure objects in your home. The measurements can be any number of ones, and they will vary a bit depending on whether you are using a measuring jug, a measuring jug measuring spoon or a measuring jug

# %%
# question 17 - dinner plate
question = "What is a dinner plate?"
answer = "a ceramic large plate usually 10 inches in diameter used for the main course of a meal, it is usually kept in a kitchen cupboard. "

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a dinner plate?
# Answer: a ceramic large plate usually 10 inches in diameter used for the main course of a meal, it is usually kept in a kitchen cupboard.
# Answer generated by GPT-2
# What is a dinner plate?
#
# A plate is an add-on for a meal. A plate is made of fresh ingredients like fresh vegetables, nuts, seeds, and herbs that are cooked to the desired level. This includes cooking fruits, vegetables, and nuts.

# %%
# question 18 - rolling pin
question = "What is a rolling pin?"
answer = "a long wooden or plastic cylinder for rolling out dough, it is usually kept in a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a rolling pin?
# Answer: a long wooden or plastic cylinder for rolling out dough, it is usually kept in a kitchen drawer.
# Answer generated by GPT-2
# What is a rolling pin? A rolling pin is a digital or LCD screen which is printed out in the form of a rectangular disk. The disk is inserted into the disk via a screwdriver. The disk is also printed out using a magnetic tape (MOSFET) or

# %%
# question 19 - food processor
question = "What is a food processor?"
answer = "an electric kitchen appliance with a set of interchangeable blades revolving inside a container, it is usually kept in a kitchen cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a food processor?
# Answer: an electric kitchen appliance with a set of interchangeable blades revolving inside a container, it is usually kept in a kitchen cupboard.
# Answer generated by GPT-2
# What is a food processor?
#
# A food processor is a computer program that converts food into food by dissolving, or "creating" food. Food processors are particularly useful for food processing which requires a computer program to program a large number of processors.
#
# How do

# %%
# question 20 - dinner fork
question = "What is a dinner fork?"
answer = "a large metal fork with 3 or 4 times, it is usually found in a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a dinner fork?
# Answer: a large metal fork with 3 or 4 times, it is usually found in a kitchen drawer.
# Answer generated by GPT-2
# What is a dinner fork?
#
# A meal fork is a simple piece of pasta or pastry you cut into pieces. The idea is that you will have a large enough supply of noodles and a small enough supply of cheese to make up to about 6 cups. As you cut the

# %%
# question 21 - pastry brush
question = "What is a pastry brush?"
answer = "also known as a basting brush, it is a wooden or plastic cooking utensil used to spread butter, oil or glaze on food, it is usually kept in a kitchen  drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a pastry brush?
# Answer: also known as a basting brush, it is a wooden or plastic cooking utensil used to spread butter, oil or glaze on food, it is usually kept in a kitchen  drawer.
# Answer generated by GPT-2
# What is a pastry brush?
#
# A pastry brush can be very useful for creating a perfect cut. Many people use it as an accessory for the shaker.
#
# A pastry brush is a tool that helps make a cut. It takes up a lot of space in your

# %%
# question 22 - fridge
question = "What is a fridge?"
answer = "an appliance for keeping food or other items cool, it is usually found in a kitchen or utility room."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a fridge?
# Answer: an appliance for keeping food or other items cool, it is usually found in a kitchen or utility room.
# Answer generated by GPT-2
# What is a fridge? A fridge is a portable storage unit that can be used when a computer is not in use and that is shut off when the computer is not in use. In this case, the refrigerator is an actual refrigerator with no openings to allow the computer to be

# %%
# question 23 - casserole dish
question = "What is a casserole dish?"
answer = "a large and deep, glass or ceramic cooking bowl, it is usually kept in a kitchen cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a casserole dish?
# Answer: a large and deep, glass or ceramic cooking bowl, it is usually kept in a kitchen cupboard.
# Answer generated by GPT-2
# What is a casserole dish? It's a dish that you eat and then you're down to your last lemon. It has almost no nutritional value.
#
# I'll give you the recipe for a casserole dish that's super easy to make and not too hard to figure

# %%
# question 24 - teaspoon
question = "What is a teaspoon?"
answer = "a small spoon that is used especially for eating soft foods and stirring beverages and that holds about one third of a tablespoon, it is usually stored in a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a teaspoon?
# Answer: a small spoon that is used especially for eating soft foods and stirring beverages and that holds about one third of a tablespoon, it is usually stored in a kitchen drawer.
# Answer generated by GPT-2
# What is a teaspoon?
#
# "A teaspoon used to measure a food is about three inches long and about three inches wide. They are called a foot, an inch and a half, and a half to be exact. A tablespoon is a small object that has a slightly

# %%
# question 25 - wooden spoon
question = "What is a wooden spoon?"
answer = "a large wooden spoon for stirring ingredients, it is usually stored in a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a wooden spoon?
# Answer: a large wooden spoon for stirring ingredients, it is usually stored in a kitchen drawer.
# Answer generated by GPT-2
# What is a wooden spoon?
#
# A wooden spoon is a wooden spoon that is used to hold small pieces of food in place. It may be used to scoop the food up or just to make a little bit of soup. It is considered to be either a spoon or a

# %%
# question 26 - chopsticks
question = "What is a chopsticks?"
answer = "a pair of slender plastic or wooden sticks held between thumb and fingers and used chiefly in Asian countries to lift food to the mouth, they are usually stored in a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a chopsticks?
# Answer: a pair of slender plastic or wooden sticks held between thumb and fingers and used chiefly in Asian countries to lift food to the mouth, they are usually stored in a kitchen drawer.
# Answer generated by GPT-2
# What is a chopsticks?
#
# A chopstick is a metal or plastic tool used to thicken or temper a vegetable or open a vegetable. A chopstick can be used to remove a spoon, a spoon, or other form of appliance. A chopstick can be used

# %%
# question 27 - colander
question = "What is a colander?"
answer = "a perforated plastic or metal cylinder for washing or draining food, it is usually stored in a kitchen cupboard."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a colander?
# Answer: a perforated plastic or metal cylinder for washing or draining food, it is usually stored in a kitchen cupboard.
# Answer generated by GPT-2
# What is a colander?
#
# A colander is a disposable container for your food or water. It's a small plastic container that can be used to store your food, water, or any other food item you are eating. It can also be used to clean containers,

# %%
# question 28 - filleting knife
question = "What is a fillet knife?"
answer = "a blunt metal concave knife or a flexible wire tool used to flesh a skin or hide, it is usually stored in a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a fillet knife?
# Answer: a blunt metal concave knife or a flexible wire tool used to flesh a skin or hide, it is usually stored in a kitchen drawer.
# Answer generated by GPT-2
# What is a fillet knife?
#
# A fillet knife is a knife or utensil that has a blade that is cut through a cutlass and any other features that make it suitable for cutting flesh or animal flesh. It has a blade that is cut through a cutlass

# %%
# question 29 - fish slice
question = "What is a fish slice?"
answer = "a metal or plastic kitchen tool that has a handle which is bent upward, and a wide, thin blade used for lifting and turning foods on a hot surface, it is usually stored in a kitchen drawer."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a fish slice?
# Answer: a metal or plastic kitchen tool that has a handle which is bent upward, and a wide, thin blade used for lifting and turning foods on a hot surface, it is usually stored in a kitchen drawer.
# Answer generated by GPT-2
# What is a fish slice?
#
# An oyster. An elk bite.
#
# What are the best parts?
#
# Toasts.
#
# And in general, what do you love about your fish and your food?
#
# I like the texture of my fish

# %%
# question 30 - bottle opener
question = "What is a bottle opener?"
answer = "a tool used to remove metal tops from some bottles, it is usually stored in a kitchen draw."

print("Question: "+question)
print("Answer: "+answer)
print("Answer generated by GPT-2")
generateAnswer(question)
# Out:
# Question: What is a bottle opener?
# Answer: a tool used to remove metal tops from some bottles, it is usually stored in a kitchen draw.
# Answer generated by GPT-2
# What is a bottle opener? It's kind of like the 'You Have to Know What You're Doing' thing, and it's a pretty big one.
#
# "I think it's a great idea for a boy to understand what he's doing directly, and then [
